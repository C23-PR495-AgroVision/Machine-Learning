# %% [markdown]
# # **Preparations**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

base_dir = '/content/drive/MyDrive/Bell Pepper'

print("Contents of base directory:")
print(os.listdir(base_dir))

print("\nContents of train directory:")
print(os.listdir(f'{base_dir}/train'))

print("\nContents of validation directory:")
print(os.listdir(f'{base_dir}/valid'))
# Out:
# Contents of base directory:
# ['valid', 'train']
#
# Contents of train directory:
# ['ripe', 'old', 'damaged', 'dried', 'unripe']
#
# Contents of validation directory:
# ['damaged', 'dried', 'old', 'unripe', 'ripe']

# %%
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'valid')

# Directory with training pictures
train_damaged_dir = os.path.join(train_dir, 'damaged')
train_unripe_dir = os.path.join(train_dir, 'unripe')
train_ripe_dir = os.path.join(train_dir, 'ripe')
train_dried_dir = os.path.join(train_dir, 'dried')
train_old_dir = os.path.join(train_dir, 'old')

# Directory with validation pictures
validation_damaged_dir = os.path.join(validation_dir, 'damaged')
validation_unripe_dir = os.path.join(validation_dir, 'unripe')
validation_ripe_dir = os.path.join(validation_dir, 'ripe')
validation_dried_dir = os.path.join(validation_dir, 'dried')
validation_old_dir = os.path.join(validation_dir, 'old')

# %%
train_damaged_fnames = os.listdir(train_damaged_dir)
train_unripe_fnames = os.listdir(train_unripe_dir)
train_ripe_fnames = os.listdir(train_ripe_dir)
train_dried_fnames = os.listdir(train_dried_dir)
train_old_fnames = os.listdir(train_old_dir)

print(train_damaged_fnames[:10])
print(train_unripe_fnames[:10])
print(train_ripe_fnames[:10])
print(train_dried_fnames[:10])
print(train_old_fnames[:10])
# Out:
# ['IMG_20220609_091107.jpg', 'IMG_20220609_091100.jpg', 'IMG_20220609_091118.jpg', 'IMG_20220609_091127.jpg', 'IMG_20220609_091103.jpg', 'IMG_20220609_091129.jpg', 'IMG_20220609_091109.jpg', 'IMG_20220609_091146.jpg', 'IMG_20220609_091136.jpg', 'IMG_20220609_091140.jpg']
# ['IMG_20220530_085312.jpg', 'IMG_20220530_085308.jpg', 'IMG_20220530_085318.jpg']
# ['IMG_20220530_085144.jpg', 'IMG_20220530_085143.jpg', 'IMG_20220530_085145.jpg', 'IMG_20220530_085148.jpg', 'IMG_20220530_085203.jpg', 'IMG_20220530_085204.jpg', 'IMG_20220530_085149.jpg', 'IMG_20220530_085202.jpg', 'IMG_20220530_085207.jpg', 'IMG_20220530_085219.jpg']
# ['IMG_20220612_152437.jpg', 'IMG_20220612_152450.jpg', 'IMG_20220612_152449.jpg', 'IMG_20220612_152441.jpg', 'IMG_20220612_152508.jpg', 'IMG_20220612_152452.jpg', 'IMG_20220612_152505.jpg', 'IMG_20220612_152458.jpg', 'IMG_20220612_152533.jpg', 'IMG_20220612_152531.jpg']
# ['IMG_20220601_093915.jpg', 'IMG_20220601_093917.jpg', 'IMG_20220601_093922.jpg', 'IMG_20220601_093918.jpg', 'IMG_20220601_093930.jpg', 'IMG_20220601_093936.jpg', 'IMG_20220601_093938.jpg', 'IMG_20220601_093941.jpg', 'IMG_20220601_094008.jpg', 'IMG_20220601_094005.jpg']

# %%
print('total training `damaged` images:', len(os.listdir(train_damaged_dir)))
print('total training `unripe` images:', len(os.listdir(train_unripe_dir)))
print('total training `ripe` images:', len(os.listdir(train_ripe_dir)))
print('total training `dried` images:', len(os.listdir(train_dried_dir)))
print('total training `old` images:', len(os.listdir(train_old_dir)))

print('total validation `damaged` images:', len(os.listdir(validation_damaged_dir)))
print('total validation `unripe` images:', len(os.listdir(validation_unripe_dir)))
print('total validation `ripe` images:', len(os.listdir(validation_ripe_dir)))
print('total validation `dried` images:', len(os.listdir(validation_dried_dir)))
print('total validation `old` images:', len(os.listdir(validation_old_dir)))
# Out:
# total training `damaged` images: 21
# total training `unripe` images: 3
# total training `ripe` images: 183
# total training `dried` images: 113
# total training `old` images: 104
# total validation `damaged` images: 10
# total validation `unripe` images: 2
# total validation `ripe` images: 60
# total validation `dried` images: 49
# total validation `old` images: 42

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

nrows = 8
ncols = 4

pic_index = 0

# %%
fig = plt.gcf()
fig.set_size_inches(ncols*5, nrows*5)

pic_index += 8

next_damaged_pix = [os.path.join(train_damaged_dir, fname) 
                for fname in train_damaged_fnames[pic_index-8 : pic_index] 
               ]

next_unripe_pix = [os.path.join(train_unripe_dir, fname) 
                for fname in train_unripe_fnames[ pic_index-8 : pic_index]
               ]

next_ripe_pix = [os.path.join(train_ripe_dir, fname) 
                for fname in train_ripe_fnames[pic_index-8 : pic_index] 
               ]

next_dried_pix = [os.path.join(train_dried_dir, fname) 
                for fname in train_dried_fnames[ pic_index-8 : pic_index]
               ]

next_old_pix = [os.path.join(train_old_dir, fname) 
                for fname in train_old_fnames[ pic_index-8 : pic_index]
               ]

for i, img_path in enumerate(next_damaged_pix + next_unripe_pix + next_ripe_pix + next_dried_pix + next_old_pix):
  sp = plt.subplot(nrows, ncols, i+1)
  sp.axis('Off')
  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
from google.colab import files

# %% [markdown]
# # **Self-Created Model Arch with Non-Augmented Data & No Callback(s)**

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(5, activation='softmax')
])

# %%
model.summary()

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255.)
test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(150, 150))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(150, 150))

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator
    )

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Self-Created Model Arch with Non-Augmented Data & No Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Self-Created Model Arch with Non-Augmented Data & No Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # **Self-Created Model Arch with Augmented Data & Callback(s)**

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(5, activation='softmax')
])

# %%
model.summary()

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=80,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(150, 150))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(150, 150))

# %%
# Defining Callbacks

# Save the best model
file_path = '/content/checkpoint/self_created'
checkpoint_callback = ModelCheckpoint(filepath=file_path, save_best_only=True, monitor='val_accuracy', verbose=2)

# Early stopping
early_stopping_callback = EarlyStopping(monitor='val_accuracy', patience=10, verbose=2, restore_best_weights=True)

# Reduce learning rate
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=2, min_lr=1e-6)

callbacks=[checkpoint_callback, early_stopping_callback, reduce_lr_callback]

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=callbacks
    )

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Self-Created Model Arch with Augmented Data & Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Self-Created Model Arch with Augmented Data & Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # **Transfer Learning (Xception) with Augmented Data & Callback(s)**

# %%
from tensorflow.keras.applications import Xception

# %%
model = tf.keras.models.Sequential([
    # Xception Layer
    Xception(include_top=False, weights='imagenet', input_shape=(224, 224, 3)),
    # Max Pooling Layer
    tf.keras.layers.GlobalMaxPooling2D(),
    # Drop Out Layer
    tf.keras.layers.Dropout(0.2),
    # 256 neuron hidden layer
    tf.keras.layers.Dense(256, activation='relu'),
    # Output
    tf.keras.layers.Dense(5, activation='softmax') 
])

model.layers[0].trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 1s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  global_max_pooling2d (Globa  (None, 2048)             0
#  lMaxPooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  dense_1 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 21,387,309
# Trainable params: 525,829
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=80,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(224, 224))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(224, 224))
# Out:
# Found 424 images belonging to 5 classes.
# Found 163 images belonging to 5 classes.

# %%
# Defining Callbacks

# Save the best model
file_path = '/content/checkpoint/xception'
checkpoint_callback = ModelCheckpoint(filepath=file_path, save_best_only=True, monitor='val_accuracy', verbose=2)

# Early stopping
early_stopping_callback = EarlyStopping(monitor='val_accuracy', patience=10, verbose=2, restore_best_weights=True)

# Reduce learning rate
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=2, min_lr=1e-6)

callbacks=[checkpoint_callback, early_stopping_callback, reduce_lr_callback]

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=callbacks
    )
# Out:
# Epoch 1/50
# 14/14 [==============================] - ETA: 0s - loss: 3.0355 - accuracy: 0.4929
# Epoch 1: val_accuracy improved from -inf to 0.53374, saving model to /content/checkpoint/xception
# 14/14 [==============================] - 93s 6s/step - loss: 3.0355 - accuracy: 0.4929 - val_loss: 2.1324 - val_accuracy: 0.5337 - lr: 0.0010
# Epoch 2/50
# 14/14 [==============================] - ETA: 0s - loss: 1.2248 - accuracy: 0.6557
# Epoch 2: val_accuracy improved from 0.53374 to 0.78528, saving model to /content/checkpoint/xception
# 14/14 [==============================] - 25s 2s/step - loss: 1.2248 - accuracy: 0.6557 - val_loss: 0.7036 - val_accuracy: 0.7853 - lr: 0.0010
# Epoch 3/50
# 14/14 [==============================] - ETA: 0s - loss: 0.6846 - accuracy: 0.7453
# Epoch 3: val_accuracy did not improve from 0.78528
# 14/14 [==============================] - 8s 560ms/step - loss: 0.6846 - accuracy: 0.7453 - val_loss: 0.6118 - val_accuracy: 0.7730 - lr: 0.0010
# Epoch 4/50
# 14/14 [==============================] - ETA: 0s - loss: 0.4893 - accuracy: 0.7995
# Epoch 4: val_accuracy did not improve from 0.78528
# 14/14 [==============================] - 6s 460ms/step - loss: 0.4893 - accuracy: 0.7995 - val_loss: 0.6979 - val_accuracy: 0.7117 - lr: 0.0010
# Epoch 5/50
# 14/14 [==============================] - ETA: 0s - loss: 0.5131 - accuracy: 0.7995
# Epoch 5: val_accuracy did not improve from 0.78528
# 14/14 [==============================] - 7s 455ms/step - loss: 0.5131 - accuracy: 0.7995 - val_loss: 0.5596 - val_accuracy: 0.7669 - lr: 0.0010
# Epoch 6/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3912 - accuracy: 0.8608
# Epoch 6: val_accuracy did not improve from 0.78528
# 14/14 [==============================] - 8s 548ms/step - loss: 0.3912 - accuracy: 0.8608 - val_loss: 0.4947 - val_accuracy: 0.7730 - lr: 0.0010
# Epoch 7/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3765 - accuracy: 0.8538
# Epoch 7: val_accuracy improved from 0.78528 to 0.84049, saving model to /content/checkpoint/xception
# 14/14 [==============================] - 25s 2s/step - loss: 0.3765 - accuracy: 0.8538 - val_loss: 0.4368 - val_accuracy: 0.8405 - lr: 0.0010
# Epoch 8/50
# 14/14 [==============================] - ETA: 0s - loss: 0.4038 - accuracy: 0.8443
# Epoch 8: val_accuracy did not improve from 0.84049
# 14/14 [==============================] - 7s 457ms/step - loss: 0.4038 - accuracy: 0.8443 - val_loss: 0.5892 - val_accuracy: 0.7853 - lr: 0.0010
# Epoch 9/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3758 - accuracy: 0.8373
# Epoch 9: val_accuracy did not improve from 0.84049
# 14/14 [==============================] - 7s 493ms/step - loss: 0.3758 - accuracy: 0.8373 - val_loss: 0.4085 - val_accuracy: 0.8098 - lr: 0.0010
# Epoch 10/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3661 - accuracy: 0.8325
# Epoch 10: val_accuracy did not improve from 0.84049
# 14/14 [==============================] - 7s 513ms/step - loss: 0.3661 - accuracy: 0.8325 - val_loss: 0.4302 - val_accuracy: 0.8160 - lr: 0.0010
# Epoch 11/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3095 - accuracy: 0.8632
# Epoch 11: val_accuracy did not improve from 0.84049
# 14/14 [==============================] - 7s 477ms/step - loss: 0.3095 - accuracy: 0.8632 - val_loss: 0.4068 - val_accuracy: 0.8098 - lr: 0.0010
# Epoch 12/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3433 - accuracy: 0.8632
# Epoch 12: val_accuracy did not improve from 0.84049
# 14/14 [==============================] - 8s 573ms/step - loss: 0.3433 - accuracy: 0.8632 - val_loss: 0.4534 - val_accuracy: 0.7914 - lr: 0.0010
# Epoch 13/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3332 - accuracy: 0.8443
# Epoch 13: val_accuracy did not improve from 0.84049
# 14/14 [==============================] - 6s 457ms/step - loss: 0.3332 - accuracy: 0.8443 - val_loss: 0.3936 - val_accuracy: 0.8282 - lr: 0.0010
# Epoch 14/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2809 - accuracy: 0.8844
# Epoch 14: val_accuracy did not improve from 0.84049
# 14/14 [==============================] - 8s 546ms/step - loss: 0.2809 - accuracy: 0.8844 - val_loss: 0.4409 - val_accuracy: 0.7669 - lr: 0.0010
# Epoch 15/50
# 14/14 [==============================] - ETA: 0s - loss: 0.4024 - accuracy: 0.8302
# Epoch 15: val_accuracy did not improve from 0.84049
# 14/14 [==============================] - 8s 553ms/step - loss: 0.4024 - accuracy: 0.8302 - val_loss: 0.4523 - val_accuracy: 0.8037 - lr: 0.0010
# Epoch 16/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3292 - accuracy: 0.8774
# Epoch 16: val_accuracy did not improve from 0.84049
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 14/14 [==============================] - 7s 457ms/step - loss: 0.3292 - accuracy: 0.8774 - val_loss: 0.3970 - val_accuracy: 0.7975 - lr: 0.0010
# Epoch 17/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2839 - accuracy: 0.8868
# Epoch 17: val_accuracy did not improve from 0.84049
# Restoring model weights from the end of the best epoch: 7.
# 14/14 [==============================] - 8s 552ms/step - loss: 0.2839 - accuracy: 0.8868 - val_loss: 0.3502 - val_accuracy: 0.8221 - lr: 1.0000e-04
# Epoch 17: early stopping

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Transfer Learning (Xception) with Augmented Data & Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Transfer Learning (Xception) with Augmented Data & Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# !zip -r /content/bellpepper_xception.zip /content/checkpoint/xception
# Out:
#   adding: content/checkpoint/xception/ (stored 0%)
#   adding: content/checkpoint/xception/variables/ (stored 0%)
#   adding: content/checkpoint/xception/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: content/checkpoint/xception/variables/variables.index (deflated 76%)
#   adding: content/checkpoint/xception/assets/ (stored 0%)
#   adding: content/checkpoint/xception/fingerprint.pb (stored 0%)
#   adding: content/checkpoint/xception/saved_model.pb (deflated 92%)
#   adding: content/checkpoint/xception/keras_metadata.pb (deflated 96%)

# %%
files.download("/content/bellpepper_xception.zip")

# %% [markdown]
# # **Transfer Learning (MobileNetV2) with Augmented Data & Callback(s)**

# %%
from tensorflow.keras.applications import MobileNetV2

# %%
model = tf.keras.models.Sequential([
    # MobileNetV2 Layer
    MobileNetV2(include_top=False, weights='imagenet', input_shape=(224, 224, 3)),
    # Max Pooling Layer
    tf.keras.layers.GlobalMaxPooling2D(),
    # Drop Out Layer
    tf.keras.layers.Dropout(0.2),
    # 256 neuron hidden layer
    tf.keras.layers.Dense(256, activation='relu'),
    # Output
    tf.keras.layers.Dense(5, activation='softmax') 
])

model.layers[0].trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_max_pooling2d_1 (Glo  (None, 1280)             0
#  balMaxPooling2D)
#
#  dropout_1 (Dropout)         (None, 1280)              0
#
#  dense_2 (Dense)             (None, 256)               327936
#
#  dense_3 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 2,587,205
# Trainable params: 329,221
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=80,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(224, 224))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(224, 224))
# Out:
# Found 424 images belonging to 5 classes.
# Found 163 images belonging to 5 classes.

# %%
# Defining Callbacks

# Save the best model
file_path = '/content/checkpoint/mobilenetv2'
checkpoint_callback = ModelCheckpoint(filepath=file_path, save_best_only=True, monitor='val_accuracy', verbose=2)

# Early stopping
early_stopping_callback = EarlyStopping(monitor='val_accuracy', patience=10, verbose=2, restore_best_weights=True)

# Reduce learning rate
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=2, min_lr=1e-6)

callbacks=[checkpoint_callback, early_stopping_callback, reduce_lr_callback]

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=callbacks
    )
# Out:
# Epoch 1/50
# 14/14 [==============================] - ETA: 0s - loss: 2.5497 - accuracy: 0.5330
# Epoch 1: val_accuracy improved from -inf to 0.71779, saving model to /content/checkpoint/mobilenetv2
# 14/14 [==============================] - 33s 2s/step - loss: 2.5497 - accuracy: 0.5330 - val_loss: 1.1134 - val_accuracy: 0.7178 - lr: 0.0010
# Epoch 2/50
# 14/14 [==============================] - ETA: 0s - loss: 0.9370 - accuracy: 0.7524
# Epoch 2: val_accuracy improved from 0.71779 to 0.74233, saving model to /content/checkpoint/mobilenetv2
# 14/14 [==============================] - 27s 2s/step - loss: 0.9370 - accuracy: 0.7524 - val_loss: 1.0179 - val_accuracy: 0.7423 - lr: 0.0010
# Epoch 3/50
# 14/14 [==============================] - ETA: 0s - loss: 0.9379 - accuracy: 0.7642
# Epoch 3: val_accuracy did not improve from 0.74233
# 14/14 [==============================] - 6s 430ms/step - loss: 0.9379 - accuracy: 0.7642 - val_loss: 1.0884 - val_accuracy: 0.7362 - lr: 0.0010
# Epoch 4/50
# 14/14 [==============================] - ETA: 0s - loss: 0.7973 - accuracy: 0.8066
# Epoch 4: val_accuracy improved from 0.74233 to 0.77301, saving model to /content/checkpoint/mobilenetv2
# 14/14 [==============================] - 27s 2s/step - loss: 0.7973 - accuracy: 0.8066 - val_loss: 0.8653 - val_accuracy: 0.7730 - lr: 0.0010
# Epoch 5/50
# 14/14 [==============================] - ETA: 0s - loss: 0.9652 - accuracy: 0.7807
# Epoch 5: val_accuracy did not improve from 0.77301
# 14/14 [==============================] - 8s 563ms/step - loss: 0.9652 - accuracy: 0.7807 - val_loss: 0.6585 - val_accuracy: 0.7546 - lr: 0.0010
# Epoch 6/50
# 14/14 [==============================] - ETA: 0s - loss: 0.9220 - accuracy: 0.7335
# Epoch 6: val_accuracy did not improve from 0.77301
# 14/14 [==============================] - 6s 431ms/step - loss: 0.9220 - accuracy: 0.7335 - val_loss: 1.0260 - val_accuracy: 0.6564 - lr: 0.0010
# Epoch 7/50
# 14/14 [==============================] - ETA: 0s - loss: 0.4720 - accuracy: 0.8349
# Epoch 7: val_accuracy improved from 0.77301 to 0.79141, saving model to /content/checkpoint/mobilenetv2
# 14/14 [==============================] - 27s 2s/step - loss: 0.4720 - accuracy: 0.8349 - val_loss: 0.5177 - val_accuracy: 0.7914 - lr: 0.0010
# Epoch 8/50
# 14/14 [==============================] - ETA: 0s - loss: 0.4912 - accuracy: 0.8208
# Epoch 8: val_accuracy improved from 0.79141 to 0.82209, saving model to /content/checkpoint/mobilenetv2
# 14/14 [==============================] - 27s 2s/step - loss: 0.4912 - accuracy: 0.8208 - val_loss: 0.6585 - val_accuracy: 0.8221 - lr: 0.0010
# Epoch 9/50
# 14/14 [==============================] - ETA: 0s - loss: 0.5798 - accuracy: 0.8066
# Epoch 9: val_accuracy did not improve from 0.82209
# 14/14 [==============================] - 7s 525ms/step - loss: 0.5798 - accuracy: 0.8066 - val_loss: 0.6322 - val_accuracy: 0.8098 - lr: 0.0010
# Epoch 10/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3949 - accuracy: 0.8632
# Epoch 10: val_accuracy improved from 0.82209 to 0.85276, saving model to /content/checkpoint/mobilenetv2
# 14/14 [==============================] - 27s 2s/step - loss: 0.3949 - accuracy: 0.8632 - val_loss: 0.3743 - val_accuracy: 0.8528 - lr: 0.0010
# Epoch 11/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3530 - accuracy: 0.8632
# Epoch 11: val_accuracy did not improve from 0.85276
# 14/14 [==============================] - 6s 452ms/step - loss: 0.3530 - accuracy: 0.8632 - val_loss: 0.3831 - val_accuracy: 0.8528 - lr: 0.0010
# Epoch 12/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3960 - accuracy: 0.8396
# Epoch 12: val_accuracy did not improve from 0.85276
# 14/14 [==============================] - 6s 433ms/step - loss: 0.3960 - accuracy: 0.8396 - val_loss: 0.4124 - val_accuracy: 0.8466 - lr: 0.0010
# Epoch 13/50
# 14/14 [==============================] - ETA: 0s - loss: 0.4322 - accuracy: 0.8396
# Epoch 13: val_accuracy improved from 0.85276 to 0.85890, saving model to /content/checkpoint/mobilenetv2
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 14/14 [==============================] - 29s 2s/step - loss: 0.4322 - accuracy: 0.8396 - val_loss: 0.3775 - val_accuracy: 0.8589 - lr: 0.0010
# Epoch 14/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3376 - accuracy: 0.8844
# Epoch 14: val_accuracy did not improve from 0.85890
# 14/14 [==============================] - 6s 437ms/step - loss: 0.3376 - accuracy: 0.8844 - val_loss: 0.3394 - val_accuracy: 0.8466 - lr: 1.0000e-04
# Epoch 15/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3189 - accuracy: 0.8585
# Epoch 15: val_accuracy did not improve from 0.85890
# 14/14 [==============================] - 7s 522ms/step - loss: 0.3189 - accuracy: 0.8585 - val_loss: 0.3201 - val_accuracy: 0.8589 - lr: 1.0000e-04
# Epoch 16/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2766 - accuracy: 0.8868
# Epoch 16: val_accuracy improved from 0.85890 to 0.86503, saving model to /content/checkpoint/mobilenetv2
# 14/14 [==============================] - 28s 2s/step - loss: 0.2766 - accuracy: 0.8868 - val_loss: 0.3284 - val_accuracy: 0.8650 - lr: 1.0000e-04
# Epoch 17/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3141 - accuracy: 0.8774
# Epoch 17: val_accuracy did not improve from 0.86503
# 14/14 [==============================] - 6s 426ms/step - loss: 0.3141 - accuracy: 0.8774 - val_loss: 0.3324 - val_accuracy: 0.8528 - lr: 1.0000e-04
# Epoch 18/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2835 - accuracy: 0.8915
# Epoch 18: val_accuracy did not improve from 0.86503
# 14/14 [==============================] - 7s 516ms/step - loss: 0.2835 - accuracy: 0.8915 - val_loss: 0.3175 - val_accuracy: 0.8589 - lr: 1.0000e-04
# Epoch 19/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2765 - accuracy: 0.8821
# Epoch 19: val_accuracy did not improve from 0.86503
# 14/14 [==============================] - 6s 432ms/step - loss: 0.2765 - accuracy: 0.8821 - val_loss: 0.3199 - val_accuracy: 0.8589 - lr: 1.0000e-04
# Epoch 20/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2764 - accuracy: 0.8962
# Epoch 20: val_accuracy did not improve from 0.86503
# 14/14 [==============================] - 7s 493ms/step - loss: 0.2764 - accuracy: 0.8962 - val_loss: 0.3127 - val_accuracy: 0.8528 - lr: 1.0000e-04
# Epoch 21/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2615 - accuracy: 0.8915
# Epoch 21: val_accuracy did not improve from 0.86503
# 14/14 [==============================] - 7s 497ms/step - loss: 0.2615 - accuracy: 0.8915 - val_loss: 0.3066 - val_accuracy: 0.8589 - lr: 1.0000e-04
# Epoch 22/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2720 - accuracy: 0.8915
# Epoch 22: val_accuracy did not improve from 0.86503
# 14/14 [==============================] - 6s 444ms/step - loss: 0.2720 - accuracy: 0.8915 - val_loss: 0.3110 - val_accuracy: 0.8589 - lr: 1.0000e-04
# Epoch 23/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2698 - accuracy: 0.8797
# Epoch 23: val_accuracy did not improve from 0.86503
# 14/14 [==============================] - 7s 506ms/step - loss: 0.2698 - accuracy: 0.8797 - val_loss: 0.3148 - val_accuracy: 0.8589 - lr: 1.0000e-04
# Epoch 24/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2640 - accuracy: 0.8821
# Epoch 24: val_accuracy improved from 0.86503 to 0.87117, saving model to /content/checkpoint/mobilenetv2
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 14/14 [==============================] - 27s 2s/step - loss: 0.2640 - accuracy: 0.8821 - val_loss: 0.3088 - val_accuracy: 0.8712 - lr: 1.0000e-04
# Epoch 25/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2571 - accuracy: 0.8962
# Epoch 25: val_accuracy did not improve from 0.87117
# 14/14 [==============================] - 6s 432ms/step - loss: 0.2571 - accuracy: 0.8962 - val_loss: 0.3065 - val_accuracy: 0.8712 - lr: 1.0000e-05
# Epoch 26/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3200 - accuracy: 0.8608
# Epoch 26: val_accuracy did not improve from 0.87117
# 14/14 [==============================] - 7s 520ms/step - loss: 0.3200 - accuracy: 0.8608 - val_loss: 0.3053 - val_accuracy: 0.8712 - lr: 1.0000e-05
# Epoch 27/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2628 - accuracy: 0.8868
# Epoch 27: val_accuracy did not improve from 0.87117
# 14/14 [==============================] - 6s 424ms/step - loss: 0.2628 - accuracy: 0.8868 - val_loss: 0.3037 - val_accuracy: 0.8712 - lr: 1.0000e-05
# Epoch 28/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2758 - accuracy: 0.8797
# Epoch 28: val_accuracy did not improve from 0.87117
# 14/14 [==============================] - 7s 507ms/step - loss: 0.2758 - accuracy: 0.8797 - val_loss: 0.3004 - val_accuracy: 0.8589 - lr: 1.0000e-05
# Epoch 29/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2819 - accuracy: 0.8797
# Epoch 29: val_accuracy did not improve from 0.87117
# 14/14 [==============================] - 7s 515ms/step - loss: 0.2819 - accuracy: 0.8797 - val_loss: 0.3015 - val_accuracy: 0.8589 - lr: 1.0000e-05
# Epoch 30/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2801 - accuracy: 0.8892
# Epoch 30: val_accuracy did not improve from 0.87117
# 14/14 [==============================] - 6s 448ms/step - loss: 0.2801 - accuracy: 0.8892 - val_loss: 0.3025 - val_accuracy: 0.8650 - lr: 1.0000e-05
# Epoch 31/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2841 - accuracy: 0.8844
# Epoch 31: val_accuracy did not improve from 0.87117
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 14/14 [==============================] - 7s 517ms/step - loss: 0.2841 - accuracy: 0.8844 - val_loss: 0.3029 - val_accuracy: 0.8650 - lr: 1.0000e-05
# Epoch 32/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2511 - accuracy: 0.9033
# Epoch 32: val_accuracy did not improve from 0.87117
# 14/14 [==============================] - 7s 501ms/step - loss: 0.2511 - accuracy: 0.9033 - val_loss: 0.3028 - val_accuracy: 0.8650 - lr: 1.0000e-06
# Epoch 33/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2824 - accuracy: 0.8868
# Epoch 33: val_accuracy did not improve from 0.87117
# 14/14 [==============================] - 6s 425ms/step - loss: 0.2824 - accuracy: 0.8868 - val_loss: 0.3026 - val_accuracy: 0.8650 - lr: 1.0000e-06
# Epoch 34/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2444 - accuracy: 0.8986
# Epoch 34: val_accuracy did not improve from 0.87117
# Restoring model weights from the end of the best epoch: 24.
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1e-06.
# 14/14 [==============================] - 7s 550ms/step - loss: 0.2444 - accuracy: 0.8986 - val_loss: 0.3024 - val_accuracy: 0.8650 - lr: 1.0000e-06
# Epoch 34: early stopping

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Transfer Learning (MobileNetV2) with Augmented Data & Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Transfer Learning (MobileNetV2) with Augmented Data & Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# !zip -r /content/bellpepper_mobilenetv2.zip /content/checkpoint/mobilenetv2
# Out:
#   adding: content/checkpoint/mobilenetv2/ (stored 0%)
#   adding: content/checkpoint/mobilenetv2/variables/ (stored 0%)
#   adding: content/checkpoint/mobilenetv2/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: content/checkpoint/mobilenetv2/variables/variables.index (deflated 76%)
#   adding: content/checkpoint/mobilenetv2/assets/ (stored 0%)
#   adding: content/checkpoint/mobilenetv2/fingerprint.pb (stored 0%)
#   adding: content/checkpoint/mobilenetv2/saved_model.pb (deflated 91%)
#   adding: content/checkpoint/mobilenetv2/keras_metadata.pb (deflated 96%)

# %%
files.download("/content/bellpepper_mobilenetv2.zip")

# %% [markdown]
# # **Transfer Learning (Densenet121) with Augmented Data & Callback(s)**

# %%
from tensorflow.keras.applications import DenseNet121

# %%
model = tf.keras.models.Sequential([
    # DenseNet121 Layer
    DenseNet121(include_top=False, weights='imagenet', input_shape=(224, 224, 3)),
    # Max Pooling Layer
    tf.keras.layers.GlobalMaxPooling2D(),
    # Drop Out Layer
    tf.keras.layers.Dropout(0.2),
    # 256 neuron hidden layer
    tf.keras.layers.Dense(256, activation='relu'),
    # Output
    tf.keras.layers.Dense(5, activation='softmax') 
])

model.layers[0].trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet121 (Functional)    (None, 7, 7, 1024)        7037504
#
#  global_max_pooling2d_2 (Glo  (None, 1024)             0
#  balMaxPooling2D)
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 256)               262400
#
#  dense_5 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 7,301,189
# Trainable params: 263,685
# Non-trainable params: 7,037,504
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=80,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(224, 224))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(224, 224))
# Out:
# Found 424 images belonging to 5 classes.
# Found 163 images belonging to 5 classes.

# %%
# Defining Callbacks

# Save the best model
file_path = '/content/checkpoint/densenet121'
checkpoint_callback = ModelCheckpoint(filepath=file_path, save_best_only=True, monitor='val_accuracy', verbose=2)

# Early stopping
early_stopping_callback = EarlyStopping(monitor='val_accuracy', patience=10, verbose=2, restore_best_weights=True)

# Reduce learning rate
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=2, min_lr=1e-6)

callbacks=[checkpoint_callback, early_stopping_callback, reduce_lr_callback]

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=callbacks
    )
# Out:
# Epoch 1/50
# 14/14 [==============================] - ETA: 0s - loss: 3.3042 - accuracy: 0.5566
# Epoch 1: val_accuracy improved from -inf to 0.72393, saving model to /content/checkpoint/densenet121
# 14/14 [==============================] - 72s 5s/step - loss: 3.3042 - accuracy: 0.5566 - val_loss: 1.7057 - val_accuracy: 0.7239 - lr: 0.0010
# Epoch 2/50
# 14/14 [==============================] - ETA: 0s - loss: 1.3330 - accuracy: 0.6934
# Epoch 2: val_accuracy improved from 0.72393 to 0.77301, saving model to /content/checkpoint/densenet121
# 14/14 [==============================] - 58s 4s/step - loss: 1.3330 - accuracy: 0.6934 - val_loss: 0.7975 - val_accuracy: 0.7730 - lr: 0.0010
# Epoch 3/50
# 14/14 [==============================] - ETA: 0s - loss: 0.7480 - accuracy: 0.7901
# Epoch 3: val_accuracy improved from 0.77301 to 0.84049, saving model to /content/checkpoint/densenet121
# 14/14 [==============================] - 57s 4s/step - loss: 0.7480 - accuracy: 0.7901 - val_loss: 0.5564 - val_accuracy: 0.8405 - lr: 0.0010
# Epoch 4/50
# 14/14 [==============================] - ETA: 0s - loss: 0.5357 - accuracy: 0.8231
# Epoch 4: val_accuracy did not improve from 0.84049
# 14/14 [==============================] - 8s 541ms/step - loss: 0.5357 - accuracy: 0.8231 - val_loss: 0.4617 - val_accuracy: 0.8344 - lr: 0.0010
# Epoch 5/50
# 14/14 [==============================] - ETA: 0s - loss: 0.6343 - accuracy: 0.8160
# Epoch 5: val_accuracy did not improve from 0.84049
# 14/14 [==============================] - 6s 439ms/step - loss: 0.6343 - accuracy: 0.8160 - val_loss: 0.5230 - val_accuracy: 0.7914 - lr: 0.0010
# Epoch 6/50
# 14/14 [==============================] - ETA: 0s - loss: 0.5500 - accuracy: 0.8042
# Epoch 6: val_accuracy improved from 0.84049 to 0.86503, saving model to /content/checkpoint/densenet121
# 14/14 [==============================] - 58s 4s/step - loss: 0.5500 - accuracy: 0.8042 - val_loss: 0.4101 - val_accuracy: 0.8650 - lr: 0.0010
# Epoch 7/50
# 14/14 [==============================] - ETA: 0s - loss: 0.4903 - accuracy: 0.8255
# Epoch 7: val_accuracy did not improve from 0.86503
# 14/14 [==============================] - 6s 446ms/step - loss: 0.4903 - accuracy: 0.8255 - val_loss: 0.4279 - val_accuracy: 0.8650 - lr: 0.0010
# Epoch 8/50
# 14/14 [==============================] - ETA: 0s - loss: 0.4384 - accuracy: 0.8255
# Epoch 8: val_accuracy improved from 0.86503 to 0.90798, saving model to /content/checkpoint/densenet121
# 14/14 [==============================] - 60s 5s/step - loss: 0.4384 - accuracy: 0.8255 - val_loss: 0.2673 - val_accuracy: 0.9080 - lr: 0.0010
# Epoch 9/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3896 - accuracy: 0.8632
# Epoch 9: val_accuracy did not improve from 0.90798
# 14/14 [==============================] - 6s 455ms/step - loss: 0.3896 - accuracy: 0.8632 - val_loss: 0.3112 - val_accuracy: 0.8773 - lr: 0.0010
# Epoch 10/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3709 - accuracy: 0.8656
# Epoch 10: val_accuracy did not improve from 0.90798
# 14/14 [==============================] - 7s 488ms/step - loss: 0.3709 - accuracy: 0.8656 - val_loss: 0.2959 - val_accuracy: 0.8528 - lr: 0.0010
# Epoch 11/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3733 - accuracy: 0.8750
# Epoch 11: val_accuracy did not improve from 0.90798
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 14/14 [==============================] - 7s 510ms/step - loss: 0.3733 - accuracy: 0.8750 - val_loss: 0.3814 - val_accuracy: 0.8282 - lr: 0.0010
# Epoch 12/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3473 - accuracy: 0.8656
# Epoch 12: val_accuracy did not improve from 0.90798
# 14/14 [==============================] - 7s 467ms/step - loss: 0.3473 - accuracy: 0.8656 - val_loss: 0.3098 - val_accuracy: 0.8589 - lr: 1.0000e-04
# Epoch 13/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3447 - accuracy: 0.8844
# Epoch 13: val_accuracy did not improve from 0.90798
# 14/14 [==============================] - 7s 495ms/step - loss: 0.3447 - accuracy: 0.8844 - val_loss: 0.2983 - val_accuracy: 0.8589 - lr: 1.0000e-04
# Epoch 14/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3013 - accuracy: 0.8868
# Epoch 14: val_accuracy did not improve from 0.90798
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 14/14 [==============================] - 7s 466ms/step - loss: 0.3013 - accuracy: 0.8868 - val_loss: 0.2809 - val_accuracy: 0.8650 - lr: 1.0000e-04
# Epoch 15/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3309 - accuracy: 0.8726
# Epoch 15: val_accuracy did not improve from 0.90798
# 14/14 [==============================] - 7s 499ms/step - loss: 0.3309 - accuracy: 0.8726 - val_loss: 0.2778 - val_accuracy: 0.8650 - lr: 1.0000e-05
# Epoch 16/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3055 - accuracy: 0.8868
# Epoch 16: val_accuracy did not improve from 0.90798
# 14/14 [==============================] - 7s 467ms/step - loss: 0.3055 - accuracy: 0.8868 - val_loss: 0.2762 - val_accuracy: 0.8650 - lr: 1.0000e-05
# Epoch 17/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2999 - accuracy: 0.8774
# Epoch 17: val_accuracy did not improve from 0.90798
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 14/14 [==============================] - 7s 537ms/step - loss: 0.2999 - accuracy: 0.8774 - val_loss: 0.2773 - val_accuracy: 0.8650 - lr: 1.0000e-05
# Epoch 18/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3041 - accuracy: 0.8844
# Epoch 18: val_accuracy did not improve from 0.90798
# Restoring model weights from the end of the best epoch: 8.
# 14/14 [==============================] - 7s 465ms/step - loss: 0.3041 - accuracy: 0.8844 - val_loss: 0.2771 - val_accuracy: 0.8650 - lr: 1.0000e-06
# Epoch 18: early stopping

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Transfer Learning (DenseNet121) with Augmented Data & Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Transfer Learning (DenseNet121) with Augmented Data & Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# !zip -r /content/bellpepper_densenet121.zip /content/checkpoint/densenet121
# Out:
#   adding: content/checkpoint/densenet121/ (stored 0%)
#   adding: content/checkpoint/densenet121/variables/ (stored 0%)
#   adding: content/checkpoint/densenet121/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: content/checkpoint/densenet121/variables/variables.index (deflated 78%)
#   adding: content/checkpoint/densenet121/assets/ (stored 0%)
#   adding: content/checkpoint/densenet121/fingerprint.pb (stored 0%)
#   adding: content/checkpoint/densenet121/saved_model.pb (deflated 92%)
#   adding: content/checkpoint/densenet121/keras_metadata.pb (deflated 96%)

# %%
files.download("/content/bellpepper_densenet121.zip")
