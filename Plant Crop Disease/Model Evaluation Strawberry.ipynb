# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Strawberry/Non-Augmented/savedmodel/DenseNet_model1_Strawberry_Based_Non_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Strawberry/Non-Augmented/savedmodel/DenseNet_model1_Strawberry_Based_Non_Augmented.zip
#    creating: content/DenseNet_model1_Strawberry_Based_Non_Augmented/
#   inflating: content/DenseNet_model1_Strawberry_Based_Non_Augmented/keras_metadata.pb
#  extracting: content/DenseNet_model1_Strawberry_Based_Non_Augmented/fingerprint.pb
#    creating: content/DenseNet_model1_Strawberry_Based_Non_Augmented/variables/
#   inflating: content/DenseNet_model1_Strawberry_Based_Non_Augmented/variables/variables.data-00000-of-00001
#   inflating: content/DenseNet_model1_Strawberry_Based_Non_Augmented/variables/variables.index
#    creating: content/DenseNet_model1_Strawberry_Based_Non_Augmented/assets/
#   inflating: content/DenseNet_model1_Strawberry_Based_Non_Augmented/saved_model.pb

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Strawberry/Non-Augmented/savedmodel/DenseNet_model2_Strawberry_Based_Non_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Strawberry/Non-Augmented/savedmodel/DenseNet_model2_Strawberry_Based_Non_Augmented.zip
#    creating: content/DenseNet_model2_Strawberry_Based_Non_Augmented/
#   inflating: content/DenseNet_model2_Strawberry_Based_Non_Augmented/keras_metadata.pb
#  extracting: content/DenseNet_model2_Strawberry_Based_Non_Augmented/fingerprint.pb
#    creating: content/DenseNet_model2_Strawberry_Based_Non_Augmented/variables/
#   inflating: content/DenseNet_model2_Strawberry_Based_Non_Augmented/variables/variables.data-00000-of-00001
#   inflating: content/DenseNet_model2_Strawberry_Based_Non_Augmented/variables/variables.index
#    creating: content/DenseNet_model2_Strawberry_Based_Non_Augmented/assets/
#   inflating: content/DenseNet_model2_Strawberry_Based_Non_Augmented/saved_model.pb

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Strawberry/Non-Augmented/savedmodel/Strawberry_MobileNetV2_model1_Based_Non_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Strawberry/Non-Augmented/savedmodel/Strawberry_MobileNetV2_model1_Based_Non_Augmented.zip
#    creating: content/Strawberry_MobileNetV2_model1_Based_Non_Augmented/
#   inflating: content/Strawberry_MobileNetV2_model1_Based_Non_Augmented/keras_metadata.pb
#  extracting: content/Strawberry_MobileNetV2_model1_Based_Non_Augmented/fingerprint.pb
#    creating: content/Strawberry_MobileNetV2_model1_Based_Non_Augmented/variables/
#   inflating: content/Strawberry_MobileNetV2_model1_Based_Non_Augmented/variables/variables.data-00000-of-00001
#   inflating: content/Strawberry_MobileNetV2_model1_Based_Non_Augmented/variables/variables.index
#    creating: content/Strawberry_MobileNetV2_model1_Based_Non_Augmented/assets/
#   inflating: content/Strawberry_MobileNetV2_model1_Based_Non_Augmented/saved_model.pb

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Strawberry/Non-Augmented/savedmodel/Strawberry_MobileNetV2_model2_Based_Non_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Strawberry/Non-Augmented/savedmodel/Strawberry_MobileNetV2_model2_Based_Non_Augmented.zip
#    creating: content/Strawberry_MobileNetV2_model2_Based_Non_Augmented/
#   inflating: content/Strawberry_MobileNetV2_model2_Based_Non_Augmented/keras_metadata.pb
#  extracting: content/Strawberry_MobileNetV2_model2_Based_Non_Augmented/fingerprint.pb
#    creating: content/Strawberry_MobileNetV2_model2_Based_Non_Augmented/variables/
#   inflating: content/Strawberry_MobileNetV2_model2_Based_Non_Augmented/variables/variables.data-00000-of-00001
#   inflating: content/Strawberry_MobileNetV2_model2_Based_Non_Augmented/variables/variables.index
#    creating: content/Strawberry_MobileNetV2_model2_Based_Non_Augmented/assets/
#   inflating: content/Strawberry_MobileNetV2_model2_Based_Non_Augmented/saved_model.pb

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Strawberry/Non-Augmented/savedmodel/Xception_model1_Strawberry_Based_Non_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Strawberry/Non-Augmented/savedmodel/Xception_model1_Strawberry_Based_Non_Augmented.zip
#    creating: content/Xception_model1_Strawberry_Based_Non_Augmented/
#   inflating: content/Xception_model1_Strawberry_Based_Non_Augmented/keras_metadata.pb
#  extracting: content/Xception_model1_Strawberry_Based_Non_Augmented/fingerprint.pb
#    creating: content/Xception_model1_Strawberry_Based_Non_Augmented/variables/
#   inflating: content/Xception_model1_Strawberry_Based_Non_Augmented/variables/variables.data-00000-of-00001
#   inflating: content/Xception_model1_Strawberry_Based_Non_Augmented/variables/variables.index
#    creating: content/Xception_model1_Strawberry_Based_Non_Augmented/assets/
#   inflating: content/Xception_model1_Strawberry_Based_Non_Augmented/saved_model.pb

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Strawberry/Non-Augmented/savedmodel/Xception_model2_Strawberry_Based_Non_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Strawberry/Non-Augmented/savedmodel/Xception_model2_Strawberry_Based_Non_Augmented.zip
#    creating: content/Xception_model2_Strawberry_Based_Non_Augmented/
#   inflating: content/Xception_model2_Strawberry_Based_Non_Augmented/keras_metadata.pb
#  extracting: content/Xception_model2_Strawberry_Based_Non_Augmented/fingerprint.pb
#    creating: content/Xception_model2_Strawberry_Based_Non_Augmented/variables/
#   inflating: content/Xception_model2_Strawberry_Based_Non_Augmented/variables/variables.data-00000-of-00001
#   inflating: content/Xception_model2_Strawberry_Based_Non_Augmented/variables/variables.index
#    creating: content/Xception_model2_Strawberry_Based_Non_Augmented/assets/
#   inflating: content/Xception_model2_Strawberry_Based_Non_Augmented/saved_model.pb

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Strawberry/Augmented/savedmodel/Strawberry_DenseNet_model1_Based_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Strawberry/Augmented/savedmodel/Strawberry_DenseNet_model1_Based_Augmented.zip
#    creating: content/Strawberry_DenseNet_model1_Based_Augmented/
#    creating: content/Strawberry_DenseNet_model1_Based_Augmented/variables/
#   inflating: content/Strawberry_DenseNet_model1_Based_Augmented/variables/variables.index
#   inflating: content/Strawberry_DenseNet_model1_Based_Augmented/variables/variables.data-00000-of-00001
#    creating: content/Strawberry_DenseNet_model1_Based_Augmented/assets/
#   inflating: content/Strawberry_DenseNet_model1_Based_Augmented/keras_metadata.pb
#  extracting: content/Strawberry_DenseNet_model1_Based_Augmented/fingerprint.pb
#   inflating: content/Strawberry_DenseNet_model1_Based_Augmented/saved_model.pb

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Strawberry/Augmented/savedmodel/Strawberry_DenseNet_model2_Based_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Strawberry/Augmented/savedmodel/Strawberry_DenseNet_model2_Based_Augmented.zip
#    creating: content/Strawberry_DenseNet_model2_Based_Augmented/
#    creating: content/Strawberry_DenseNet_model2_Based_Augmented/variables/
#   inflating: content/Strawberry_DenseNet_model2_Based_Augmented/variables/variables.index
#   inflating: content/Strawberry_DenseNet_model2_Based_Augmented/variables/variables.data-00000-of-00001
#    creating: content/Strawberry_DenseNet_model2_Based_Augmented/assets/
#   inflating: content/Strawberry_DenseNet_model2_Based_Augmented/keras_metadata.pb
#  extracting: content/Strawberry_DenseNet_model2_Based_Augmented/fingerprint.pb
#   inflating: content/Strawberry_DenseNet_model2_Based_Augmented/saved_model.pb

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Strawberry/Augmented/savedmodel/Strawberry_MobileNetV2_model1_Based_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Strawberry/Augmented/savedmodel/Strawberry_MobileNetV2_model1_Based_Augmented.zip
#    creating: content/Strawberry_MobileNetV2_model1_Based_Augmented/
#    creating: content/Strawberry_MobileNetV2_model1_Based_Augmented/variables/
#   inflating: content/Strawberry_MobileNetV2_model1_Based_Augmented/variables/variables.index
#   inflating: content/Strawberry_MobileNetV2_model1_Based_Augmented/variables/variables.data-00000-of-00001
#    creating: content/Strawberry_MobileNetV2_model1_Based_Augmented/assets/
#   inflating: content/Strawberry_MobileNetV2_model1_Based_Augmented/keras_metadata.pb
#  extracting: content/Strawberry_MobileNetV2_model1_Based_Augmented/fingerprint.pb
#   inflating: content/Strawberry_MobileNetV2_model1_Based_Augmented/saved_model.pb

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Strawberry/Augmented/savedmodel/Strawberry_MobileNetV2_model2_Based_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Strawberry/Augmented/savedmodel/Strawberry_MobileNetV2_model2_Based_Augmented.zip
#    creating: content/Strawberry_MobileNetV2_model2_Based_Augmented/
#    creating: content/Strawberry_MobileNetV2_model2_Based_Augmented/variables/
#   inflating: content/Strawberry_MobileNetV2_model2_Based_Augmented/variables/variables.index
#   inflating: content/Strawberry_MobileNetV2_model2_Based_Augmented/variables/variables.data-00000-of-00001
#    creating: content/Strawberry_MobileNetV2_model2_Based_Augmented/assets/
#   inflating: content/Strawberry_MobileNetV2_model2_Based_Augmented/keras_metadata.pb
#  extracting: content/Strawberry_MobileNetV2_model2_Based_Augmented/fingerprint.pb
#   inflating: content/Strawberry_MobileNetV2_model2_Based_Augmented/saved_model.pb

# %%
pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install opendatasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Library to dataset
import opendatasets as od
import os
import zipfile
import numpy as np
import pandas as pd

# Surpress Warnings
import warnings
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
# library visualization
import matplotlib.pyplot as plt

# Library Tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# Others
import shutil
import random

# Confusion Matrix and Classification Report
from sklearn.metrics import confusion_matrix, classification_report
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import f1_score

# %%
# Download dataset
od.download('https://www.kaggle.com/datasets/faudyanurul/strawberry')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: faudyanurul
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 83.5M/83.5M [00:01<00:00, 60.7MB/s]

# %%
# Load dataset
print("==========================Training Data====================")
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    "strawberry/Strawberry/train",
    label_mode="categorical",
    class_names=['Strawberry___healthy', 'Strawberry___Leaf_scorch'],
    color_mode="rgb",
    batch_size=1,
    image_size=(256, 256),
    shuffle=True,
    seed=123
)
print("==========================Validation Data====================")
val_data = tf.keras.preprocessing.image_dataset_from_directory(
    "strawberry/Strawberry/valid",
    label_mode="categorical",
    class_names=['Strawberry___healthy', 'Strawberry___Leaf_scorch'],
    color_mode="rgb",
    batch_size=1,
    image_size=(256, 256),
    shuffle=False,
    seed=123
)
# Out:
# ==========================Training Data====================
# Found 3598 files belonging to 2 classes.
# ==========================Validation Data====================
# Found 900 files belonging to 2 classes.

# %%
# All images will be rescaled by 1./255.
train_datagen = ImageDataGenerator(rescale = 1.0/256.)
test_datagen  = ImageDataGenerator(rescale = 1.0/256)

# --------------------
# Flow training images in batches of 20 using train_datagen generator
# --------------------
train_generator = train_datagen.flow_from_directory("strawberry/Strawberry/train",
                                                    batch_size=20,
                                                    class_mode='categorical',
                                                    target_size=(224, 224))     
# --------------------
# Flow validation images in batches of 20 using test_datagen generator
# --------------------
validation_generator =  test_datagen.flow_from_directory("strawberry/Strawberry/valid",
                                                         batch_size=20,
                                                         class_mode  = 'categorical',
                                                         target_size = (224, 224),
                                                         shuffle=False)
# Out:
# Found 3598 images belonging to 2 classes.
# Found 900 images belonging to 2 classes.

# %% [markdown]
# Model Non Augmented Evaluating

# %% [markdown]
# Model Dense121 Version 1 Strawberry Non Augmented

# %%
# load model
import tensorflow as tf
Dense_Non_Aug1 = tf.keras.models.load_model('/content/content/DenseNet_model1_Strawberry_Based_Non_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Dense_Non_Aug1 = Dense_Non_Aug1.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Dense_Non_Aug1[1]*100))
print("Loss: %.6f%%" % (scores_Dense_Non_Aug1[0]*100))
# Out:
# ==========================Evaluate Model====================
# 45/45 [==============================] - 163s 4s/step - loss: 5.6057e-05 - accuracy: 1.0000
# Accuracy: 100.000000%
# Loss: 0.005606%

# %%
# Confusion Matrix and Classification Report
target_names = ['Strawberry___healthy', 'Strawberry___Leaf_scorch']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Dense_Non_Aug1.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_strawberry_dense_non_aug1 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_strawberry_dense_non_aug1)
# Out:
# ==========================Confusion Matrix====================
# 45/45 [==============================] - 177s 4s/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#     Strawberry___healthy       1.00      1.00      1.00       444
# Strawberry___Leaf_scorch       1.00      1.00      1.00       456
#
#                 accuracy                           1.00       900
#                macro avg       1.00      1.00      1.00       900
#             weighted avg       1.00      1.00      1.00       900
#
# ==========================F1 Score====================
# F1 Score :  1.0

# %% [markdown]
# Model Dense121 Version 2 Strawberry Non Augmented

# %%
# load model
import tensorflow as tf
Dense_Non_Aug2 = tf.keras.models.load_model('/content/content/DenseNet_model2_Strawberry_Based_Non_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Dense_Non_Aug2 = Dense_Non_Aug2.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Dense_Non_Aug2[1]*100))
print("Loss: %.6f%%" % (scores_Dense_Non_Aug2[0]*100))
# Out:
# ==========================Evaluate Model====================
# 45/45 [==============================] - 168s 4s/step - loss: 3.1709e-07 - accuracy: 1.0000
# Accuracy: 100.000000%
# Loss: 0.000032%

# %%
# Confusion Matrix and Classification Report
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Dense_Non_Aug2.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_strawberry_dense_non_aug2 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_strawberry_dense_non_aug2)
# Out:
# ==========================Confusion Matrix====================
# 45/45 [==============================] - 160s 4s/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#     Strawberry___healthy       1.00      1.00      1.00       444
# Strawberry___Leaf_scorch       1.00      1.00      1.00       456
#
#                 accuracy                           1.00       900
#                macro avg       1.00      1.00      1.00       900
#             weighted avg       1.00      1.00      1.00       900
#
# ==========================F1 Score====================
# F1 Score :  1.0

# %% [markdown]
# MobileNet V2 Version 1 Strawberry Non Augmented

# %%
# load model
import tensorflow as tf
Mobile_Non_Aug1 = tf.keras.models.load_model('/content/content/Strawberry_MobileNetV2_model1_Based_Non_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Mobile_Non_Aug1 = Mobile_Non_Aug1.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Mobile_Non_Aug1[1]*100))
print("Loss: %.6f%%" % (scores_Mobile_Non_Aug1[0]*100))
# Out:
# ==========================Evaluate Model====================
# 45/45 [==============================] - 41s 864ms/step - loss: 6.9666e-06 - accuracy: 1.0000
# Accuracy: 100.000000%
# Loss: 0.000697%

# %%
# Confusion Matrix and Classification Report
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Mobile_Non_Aug1.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_strawberry_mobile_non_aug1 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_strawberry_mobile_non_aug1)
# Out:
# ==========================Confusion Matrix====================
# 45/45 [==============================] - 40s 870ms/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#     Strawberry___healthy       1.00      1.00      1.00       444
# Strawberry___Leaf_scorch       1.00      1.00      1.00       456
#
#                 accuracy                           1.00       900
#                macro avg       1.00      1.00      1.00       900
#             weighted avg       1.00      1.00      1.00       900
#
# ==========================F1 Score====================
# F1 Score :  1.0

# %% [markdown]
# MobileNet V2 Version 2 Strawberry Non Augmented

# %%
# load model
import tensorflow as tf
Mobile_Non_Aug2 = tf.keras.models.load_model('/content/content/Strawberry_MobileNetV2_model2_Based_Non_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Mobile_Non_Aug2 = Mobile_Non_Aug2.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Mobile_Non_Aug2[1]*100))
print("Loss: %.6f%%" % (scores_Mobile_Non_Aug2[0]*100))
# Out:
# ==========================Evaluate Model====================
# 45/45 [==============================] - 39s 826ms/step - loss: 2.4489e-07 - accuracy: 1.0000
# Accuracy: 100.000000%
# Loss: 0.000024%

# %%
# Confusion Matrix and Classification Report
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Mobile_Non_Aug2.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_strawberry_mobile_non_aug2 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_strawberry_mobile_non_aug2)
# Out:
# ==========================Confusion Matrix====================
# 45/45 [==============================] - 38s 807ms/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#     Strawberry___healthy       1.00      1.00      1.00       444
# Strawberry___Leaf_scorch       1.00      1.00      1.00       456
#
#                 accuracy                           1.00       900
#                macro avg       1.00      1.00      1.00       900
#             weighted avg       1.00      1.00      1.00       900
#
# ==========================F1 Score====================
# F1 Score :  1.0

# %% [markdown]
# Xception Version 1 Strawberry Non Augmented

# %%
# load model
import tensorflow as tf
Xception_Non_Aug1 = tf.keras.models.load_model('/content/content/Xception_model1_Strawberry_Based_Non_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Xception_Non_Aug1 = Xception_Non_Aug1.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Xception_Non_Aug1[1]*100))
print("Loss: %.6f%%" % (scores_Xception_Non_Aug1[0]*100))
# Out:
# ==========================Evaluate Model====================
# 45/45 [==============================] - 215s 5s/step - loss: 5.5723e-07 - accuracy: 1.0000
# Accuracy: 100.000000%
# Loss: 0.000056%

# %%
# Confusion Matrix and Classification Report
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Xception_Non_Aug1.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_strawberry_xception_non_aug1 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_strawberry_xception_non_aug1)
# Out:
# ==========================Confusion Matrix====================
# 45/45 [==============================] - 217s 5s/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#     Strawberry___healthy       1.00      1.00      1.00       444
# Strawberry___Leaf_scorch       1.00      1.00      1.00       456
#
#                 accuracy                           1.00       900
#                macro avg       1.00      1.00      1.00       900
#             weighted avg       1.00      1.00      1.00       900
#
# ==========================F1 Score====================
# F1 Score :  1.0

# %% [markdown]
# Xception Version 2 Strawberry Non Augmented

# %%
# load model
import tensorflow as tf
Xception_Non_Aug2 = tf.keras.models.load_model('/content/content/Xception_model2_Strawberry_Based_Non_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Xception_Non_Aug2 = Xception_Non_Aug2.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Xception_Non_Aug2[1]*100))
print("Loss: %.6f%%" % (scores_Xception_Non_Aug2[0]*100))
# Out:
# ==========================Evaluate Model====================
# 45/45 [==============================] - 209s 5s/step - loss: 4.7644e-04 - accuracy: 1.0000
# Accuracy: 100.000000%
# Loss: 0.047644%

# %%
# Confusion Matrix and Classification Report
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Xception_Non_Aug2.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_strawberry_xception_non_aug2 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_strawberry_xception_non_aug2)
# Out:
# ==========================Confusion Matrix====================
# 45/45 [==============================] - 215s 5s/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#     Strawberry___healthy       1.00      1.00      1.00       444
# Strawberry___Leaf_scorch       1.00      1.00      1.00       456
#
#                 accuracy                           1.00       900
#                macro avg       1.00      1.00      1.00       900
#             weighted avg       1.00      1.00      1.00       900
#
# ==========================F1 Score====================
# F1 Score :  1.0

# %% [markdown]
# Model Augmented Evaluating

# %% [markdown]
# Model Dense121 Version 1 Strawberry Augmented

# %%
# load model
import tensorflow as tf
Dense_Aug1 = tf.keras.models.load_model('/content/content/Strawberry_DenseNet_model1_Based_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Dense_Aug1 = Dense_Aug1.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Dense_Aug1[1]*100))
print("Loss: %.6f%%" % (scores_Dense_Aug1[0]*100))
# Out:
# ==========================Evaluate Model====================
# 45/45 [==============================] - 164s 4s/step - loss: 2.3325e-05 - accuracy: 1.0000
# Accuracy: 100.000000%
# Loss: 0.002333%

# %%
# Confusion Matrix and Classification Report
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Dense_Aug1.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_strawberry_dense_aug1 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_strawberry_dense_aug1)
# Out:
# ==========================Confusion Matrix====================
# 45/45 [==============================] - 163s 4s/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#     Strawberry___healthy       1.00      1.00      1.00       444
# Strawberry___Leaf_scorch       1.00      1.00      1.00       456
#
#                 accuracy                           1.00       900
#                macro avg       1.00      1.00      1.00       900
#             weighted avg       1.00      1.00      1.00       900
#
# ==========================F1 Score====================
# F1 Score :  1.0

# %% [markdown]
# Model Dense121 Version 2 Strawberry Augmented

# %%
# load model
import tensorflow as tf
Dense_Aug2 = tf.keras.models.load_model('/content/content/Strawberry_DenseNet_model2_Based_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Dense_Aug2 = Dense_Aug2.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Dense_Aug2[1]*100))
print("Loss: %.6f%%" % (scores_Dense_Aug2[0]*100))
# Out:
# ==========================Evaluate Model====================
# 45/45 [==============================] - 162s 4s/step - loss: 3.9966e-05 - accuracy: 1.0000
# Accuracy: 100.000000%
# Loss: 0.003997%

# %%
# Confusion Matrix and Classification Report
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Dense_Aug2.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_strawberry_dense_aug2 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_strawberry_dense_aug2)
# Out:
# ==========================Confusion Matrix====================
# 45/45 [==============================] - 165s 4s/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#     Strawberry___healthy       1.00      1.00      1.00       444
# Strawberry___Leaf_scorch       1.00      1.00      1.00       456
#
#                 accuracy                           1.00       900
#                macro avg       1.00      1.00      1.00       900
#             weighted avg       1.00      1.00      1.00       900
#
# ==========================F1 Score====================
# F1 Score :  1.0

# %% [markdown]
# MobileNet V2 Version 1 Strawberry Augmented

# %%
# Load model
Mobile_Aug1 = tf.keras.models.load_model('/content/content/Strawberry_MobileNetV2_model1_Based_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Mobile_Aug1 = Mobile_Aug1.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Mobile_Aug1[1]*100))
print("Loss: %.6f%%" % (scores_Mobile_Aug1[0]*100))
# Out:
# ==========================Evaluate Model====================
# 45/45 [==============================] - 41s 895ms/step - loss: 0.0011 - accuracy: 1.0000
# Accuracy: 100.000000%
# Loss: 0.112956%

# %%
# Confusion Matrix and Classification Report
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Mobile_Aug1.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_strawberry_mobile_aug1 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_strawberry_mobile_aug1)
# Out:
# ==========================Confusion Matrix====================
# 45/45 [==============================] - 40s 859ms/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#     Strawberry___healthy       1.00      1.00      1.00       444
# Strawberry___Leaf_scorch       1.00      1.00      1.00       456
#
#                 accuracy                           1.00       900
#                macro avg       1.00      1.00      1.00       900
#             weighted avg       1.00      1.00      1.00       900
#
# ==========================F1 Score====================
# F1 Score :  1.0

# %% [markdown]
# MobileNet V2 Version 2 Strawberry Augmented

# %%
# Load model
Mobile_Aug2 = tf.keras.models.load_model('/content/content/Strawberry_MobileNetV2_model2_Based_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Mobile_Aug2 = Mobile_Aug2.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Mobile_Aug2[1]*100))
print("Loss: %.6f%%" % (scores_Mobile_Aug2[0]*100))
# Out:
# ==========================Evaluate Model====================
# 45/45 [==============================] - 43s 930ms/step - loss: 5.9113e-04 - accuracy: 1.0000
# Accuracy: 100.000000%
# Loss: 0.059113%

# %%
# Confusion Matrix and Classification Report
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Mobile_Aug2.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_strawberry_mobile_aug2 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_strawberry_mobile_aug2)
# Out:
# ==========================Confusion Matrix====================
# 45/45 [==============================] - 40s 854ms/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#     Strawberry___healthy       1.00      1.00      1.00       444
# Strawberry___Leaf_scorch       1.00      1.00      1.00       456
#
#                 accuracy                           1.00       900
#                macro avg       1.00      1.00      1.00       900
#             weighted avg       1.00      1.00      1.00       900
#
# ==========================F1 Score====================
# F1 Score :  1.0

# %% [markdown]
# Compare All

# %%
# Make dictionary of all models
models = {
    "Dense_Non_Aug1": Dense_Non_Aug1,
    "Dense_Non_Aug2": Dense_Non_Aug2,
    "Mobile_Non_Aug1": Mobile_Non_Aug1,
    "Mobile_Non_Aug2": Mobile_Non_Aug2,
    "Xception_Non_Aug1": Xception_Non_Aug1,
    "Xception_Non_Aug2": Xception_Non_Aug2,
    "Dense_Aug1": Dense_Aug1,
    "Dense_Aug2": Dense_Aug2,
    "Mobile_Aug1": Mobile_Aug1,
    "Mobile_Aug2": Mobile_Aug2,

}

# Make dictionary of all accuracy scores
accuracy = {
    "Dense_Non_Aug1": scores_Dense_Non_Aug1[1],
    "Dense_Non_Aug2": scores_Dense_Non_Aug2[1],
    "Mobile_Non_Aug1": scores_Mobile_Non_Aug1[1],
    "Mobile_Non_Aug2": scores_Mobile_Non_Aug2[1],
    "Xception_Non_Aug1": scores_Xception_Non_Aug1[1],
    "Xception_Non_Aug2": scores_Xception_Non_Aug2[1],
    "Dense_Aug1": scores_Dense_Aug1[1],
    "Dense_Aug2": scores_Dense_Aug2[1],
    "Mobile_Aug1": scores_Mobile_Aug1[1],
    "Mobile_Aug2": scores_Mobile_Aug2[1],


}

# Make dictionary of all loss scores
loss = {
    "Dense_Non_Aug1": scores_Dense_Non_Aug1[0],
    "Dense_Non_Aug2": scores_Dense_Non_Aug2[0],
    "Mobile_Non_Aug1": scores_Mobile_Non_Aug1[0],
    "Mobile_Non_Aug2": scores_Mobile_Non_Aug2[0],
    "Xception_Non_Aug1": scores_Xception_Non_Aug1[0],
    "Xception_Non_Aug2": scores_Xception_Non_Aug2[0],
    "Dense_Aug1": scores_Dense_Aug1[0],
    "Dense_Aug2": scores_Dense_Aug2[0],
    "Mobile_Aug1": scores_Mobile_Aug1[0],
    "Mobile_Aug2": scores_Mobile_Aug2[0],
}

f1 = {
    "Dense_Non_Aug1": f1_strawberry_dense_non_aug1,
    "Dense_Non_Aug2": f1_strawberry_dense_non_aug2,
    "Mobile_Non_Aug1": f1_strawberry_mobile_non_aug1,
    "Mobile_Non_Aug2": f1_strawberry_mobile_non_aug2,
    "Xception_Non_Aug1": f1_strawberry_xception_non_aug1,
    "Xception_Non_Aug2": f1_strawberry_xception_non_aug2,
    "Dense_Aug1": f1_strawberry_dense_aug1,
    "Dense_Aug2": f1_strawberry_dense_aug2,
    "Mobile_Aug1": f1_strawberry_mobile_aug1,
    "Mobile_Aug2": f1_strawberry_mobile_aug2,
}

# Make dataframe of all models, accuracy, loss, and f1 score
df = pd.DataFrame(list(zip(models.keys(), accuracy.values(), loss.values(), f1.values())), columns =['Model', 'Accuracy', 'Loss', 'F1'])

# Sort dataframe by accuracy
df = df.sort_values(by=['Accuracy'], ascending=False)

# Print dataframe
print(df)
# Out:
#                Model  Accuracy          Loss   F1
# 0     Dense_Non_Aug1       1.0  5.605728e-05  1.0
# 1     Dense_Non_Aug2       1.0  3.170912e-07  1.0
# 2    Mobile_Non_Aug1       1.0  6.966597e-06  1.0
# 3    Mobile_Non_Aug2       1.0  2.448858e-07  1.0
# 4  Xception_Non_Aug1       1.0  5.572275e-07  1.0
# 5  Xception_Non_Aug2       1.0  4.764399e-04  1.0
# 6         Dense_Aug1       1.0  2.332514e-05  1.0
# 7         Dense_Aug2       1.0  3.996587e-05  1.0
# 8        Mobile_Aug1       1.0  1.129559e-03  1.0
# 9        Mobile_Aug2       1.0  5.911288e-04  1.0

# %%
# make multiple plots for accuracy, f1 and loss with annotations
# Accuracy
plt.figure(figsize=(20, 10))
plt.title('Accuracy')
plt.bar(df['Model'], df['Accuracy'], color='green')
plt.xticks(rotation=90)
for i, v in enumerate(df['Accuracy']):
    plt.text(i - 0.25, v + 0.01, '{0:.5f}'.format(v))
plt.show()

# F1
plt.figure(figsize=(20, 10))
plt.title('F1')
plt.bar(df['Model'], df['F1'], color='green')
plt.xticks(rotation=90)
for i, v in enumerate(df['F1']):
    plt.text(i - 0.25, v + 0.01, '{0:.5f}'.format(v))
plt.show()

# Loss
plt.figure(figsize=(20, 10))
plt.title('Loss')
plt.bar(df['Model'], df['Loss'], color='green')
plt.xticks(rotation=90)
for i, v in enumerate(df['Loss']):
    plt.text(i - 0.25, v + 0.0001, '{0:.5f}'.format(v))
plt.show()
