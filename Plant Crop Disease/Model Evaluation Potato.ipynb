# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Potato/NonAugmented/savedmodel/DenseNet_model1_Potato_Based_Non_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Potato/NonAugmented/savedmodel/DenseNet_model1_Potato_Based_Non_Augmented.zip
#    creating: content/DenseNet_model1_Potato_Based_Non_Augmented/
#    creating: content/DenseNet_model1_Potato_Based_Non_Augmented/assets/
#  extracting: content/DenseNet_model1_Potato_Based_Non_Augmented/fingerprint.pb
#    creating: content/DenseNet_model1_Potato_Based_Non_Augmented/variables/
#   inflating: content/DenseNet_model1_Potato_Based_Non_Augmented/variables/variables.data-00000-of-00001
#   inflating: content/DenseNet_model1_Potato_Based_Non_Augmented/variables/variables.index
#   inflating: content/DenseNet_model1_Potato_Based_Non_Augmented/keras_metadata.pb
#   inflating: content/DenseNet_model1_Potato_Based_Non_Augmented/saved_model.pb

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Potato/NonAugmented/savedmodel/DenseNet_model2_Potato_Based_Non_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Potato/NonAugmented/savedmodel/DenseNet_model2_Potato_Based_Non_Augmented.zip
#    creating: content/DenseNet_model2_Potato_Based_Non_Augmented/
#    creating: content/DenseNet_model2_Potato_Based_Non_Augmented/assets/
#  extracting: content/DenseNet_model2_Potato_Based_Non_Augmented/fingerprint.pb
#    creating: content/DenseNet_model2_Potato_Based_Non_Augmented/variables/
#   inflating: content/DenseNet_model2_Potato_Based_Non_Augmented/variables/variables.data-00000-of-00001
#   inflating: content/DenseNet_model2_Potato_Based_Non_Augmented/variables/variables.index
#   inflating: content/DenseNet_model2_Potato_Based_Non_Augmented/keras_metadata.pb
#   inflating: content/DenseNet_model2_Potato_Based_Non_Augmented/saved_model.pb

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Potato/NonAugmented/savedmodel/Potato_MobileNetV2_model1_Based_Non_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Potato/NonAugmented/savedmodel/Potato_MobileNetV2_model1_Based_Non_Augmented.zip
#    creating: content/Potato_MobileNetV2_model1_Based_Non_Augmented/
#   inflating: content/Potato_MobileNetV2_model1_Based_Non_Augmented/keras_metadata.pb
#  extracting: content/Potato_MobileNetV2_model1_Based_Non_Augmented/fingerprint.pb
#    creating: content/Potato_MobileNetV2_model1_Based_Non_Augmented/variables/
#   inflating: content/Potato_MobileNetV2_model1_Based_Non_Augmented/variables/variables.data-00000-of-00001
#   inflating: content/Potato_MobileNetV2_model1_Based_Non_Augmented/variables/variables.index
#    creating: content/Potato_MobileNetV2_model1_Based_Non_Augmented/assets/
#   inflating: content/Potato_MobileNetV2_model1_Based_Non_Augmented/saved_model.pb

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Potato/NonAugmented/savedmodel/Potato_MobileNetV2_model2_Based_Non_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Potato/NonAugmented/savedmodel/Potato_MobileNetV2_model2_Based_Non_Augmented.zip
#    creating: content/Potato_MobileNetV2_model2_Based_Non_Augmented/
#   inflating: content/Potato_MobileNetV2_model2_Based_Non_Augmented/keras_metadata.pb
#  extracting: content/Potato_MobileNetV2_model2_Based_Non_Augmented/fingerprint.pb
#    creating: content/Potato_MobileNetV2_model2_Based_Non_Augmented/variables/
#   inflating: content/Potato_MobileNetV2_model2_Based_Non_Augmented/variables/variables.data-00000-of-00001
#   inflating: content/Potato_MobileNetV2_model2_Based_Non_Augmented/variables/variables.index
#    creating: content/Potato_MobileNetV2_model2_Based_Non_Augmented/assets/
#   inflating: content/Potato_MobileNetV2_model2_Based_Non_Augmented/saved_model.pb

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Potato/NonAugmented/savedmodel/Xception_model1_Potato_Based_Non_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Potato/NonAugmented/savedmodel/Xception_model1_Potato_Based_Non_Augmented.zip
#    creating: content/Xception_model1_Potato_Based_Non_Augmented/
#    creating: content/Xception_model1_Potato_Based_Non_Augmented/variables/
#   inflating: content/Xception_model1_Potato_Based_Non_Augmented/variables/variables.data-00000-of-00001
#   inflating: content/Xception_model1_Potato_Based_Non_Augmented/variables/variables.index
#    creating: content/Xception_model1_Potato_Based_Non_Augmented/assets/
#  extracting: content/Xception_model1_Potato_Based_Non_Augmented/fingerprint.pb
#   inflating: content/Xception_model1_Potato_Based_Non_Augmented/saved_model.pb
#   inflating: content/Xception_model1_Potato_Based_Non_Augmented/keras_metadata.pb

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Potato/NonAugmented/savedmodel/Xception_model2_Potato_Based_Non_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Potato/NonAugmented/savedmodel/Xception_model2_Potato_Based_Non_Augmented.zip
#    creating: content/Xception_model2_Potato_Based_Non_Augmented/
#    creating: content/Xception_model2_Potato_Based_Non_Augmented/variables/
#   inflating: content/Xception_model2_Potato_Based_Non_Augmented/variables/variables.data-00000-of-00001
#   inflating: content/Xception_model2_Potato_Based_Non_Augmented/variables/variables.index
#    creating: content/Xception_model2_Potato_Based_Non_Augmented/assets/
#  extracting: content/Xception_model2_Potato_Based_Non_Augmented/fingerprint.pb
#   inflating: content/Xception_model2_Potato_Based_Non_Augmented/saved_model.pb
#   inflating: content/Xception_model2_Potato_Based_Non_Augmented/keras_metadata.pb

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Potato/Augmented/Saved_model/Potato_DenseNet_model1_Based_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Potato/Augmented/Saved_model/Potato_DenseNet_model1_Based_Augmented.zip
#    creating: content/Potato_DenseNet_model1_Based_Augmented/
#   inflating: content/Potato_DenseNet_model1_Based_Augmented/saved_model.pb
#  extracting: content/Potato_DenseNet_model1_Based_Augmented/fingerprint.pb
#    creating: content/Potato_DenseNet_model1_Based_Augmented/variables/
#   inflating: content/Potato_DenseNet_model1_Based_Augmented/variables/variables.data-00000-of-00001
#   inflating: content/Potato_DenseNet_model1_Based_Augmented/variables/variables.index
#   inflating: content/Potato_DenseNet_model1_Based_Augmented/keras_metadata.pb
#    creating: content/Potato_DenseNet_model1_Based_Augmented/assets/

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Potato/Augmented/Saved_model/Potato_DenseNet_model2_Based_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Potato/Augmented/Saved_model/Potato_DenseNet_model2_Based_Augmented.zip
#    creating: content/Potato_DenseNet_model2_Based_Augmented/
#   inflating: content/Potato_DenseNet_model2_Based_Augmented/saved_model.pb
#  extracting: content/Potato_DenseNet_model2_Based_Augmented/fingerprint.pb
#    creating: content/Potato_DenseNet_model2_Based_Augmented/variables/
#   inflating: content/Potato_DenseNet_model2_Based_Augmented/variables/variables.data-00000-of-00001
#   inflating: content/Potato_DenseNet_model2_Based_Augmented/variables/variables.index
#   inflating: content/Potato_DenseNet_model2_Based_Augmented/keras_metadata.pb
#    creating: content/Potato_DenseNet_model2_Based_Augmented/assets/

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Potato/Augmented/Saved_model/Potato_MobileNetV2_model1_Based_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Potato/Augmented/Saved_model/Potato_MobileNetV2_model1_Based_Augmented.zip
#    creating: content/Potato_MobileNetV2_model1_Based_Augmented/
#   inflating: content/Potato_MobileNetV2_model1_Based_Augmented/saved_model.pb
#  extracting: content/Potato_MobileNetV2_model1_Based_Augmented/fingerprint.pb
#    creating: content/Potato_MobileNetV2_model1_Based_Augmented/variables/
#   inflating: content/Potato_MobileNetV2_model1_Based_Augmented/variables/variables.data-00000-of-00001
#   inflating: content/Potato_MobileNetV2_model1_Based_Augmented/variables/variables.index
#   inflating: content/Potato_MobileNetV2_model1_Based_Augmented/keras_metadata.pb
#    creating: content/Potato_MobileNetV2_model1_Based_Augmented/assets/

# %%
# !unzip /content/drive/MyDrive/Saved_Model/Potato/Augmented/Saved_model/Potato_MobileNetV2_model2_Based_Augmented.zip
# Out:
# Archive:  /content/drive/MyDrive/Saved_Model/Potato/Augmented/Saved_model/Potato_MobileNetV2_model2_Based_Augmented.zip
#    creating: content/Potato_MobileNetV2_model2_Based_Augmented/
#   inflating: content/Potato_MobileNetV2_model2_Based_Augmented/saved_model.pb
#  extracting: content/Potato_MobileNetV2_model2_Based_Augmented/fingerprint.pb
#    creating: content/Potato_MobileNetV2_model2_Based_Augmented/variables/
#   inflating: content/Potato_MobileNetV2_model2_Based_Augmented/variables/variables.data-00000-of-00001
#   inflating: content/Potato_MobileNetV2_model2_Based_Augmented/variables/variables.index
#   inflating: content/Potato_MobileNetV2_model2_Based_Augmented/keras_metadata.pb
#    creating: content/Potato_MobileNetV2_model2_Based_Augmented/assets/

# %%
pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install opendatasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Library to dataset
import opendatasets as od
import os
import zipfile
import numpy as np
import pandas as pd

# Surpress Warnings
import warnings
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
# library visualization
import matplotlib.pyplot as plt

# Library Tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# Others
import shutil
import random

# Confusion Matrix and Classification Report
from sklearn.metrics import confusion_matrix, classification_report
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import f1_score

# %%
# Download dataset
od.download('https://www.kaggle.com/datasets/faudyanurul/potato')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: faudyanurul
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 185M/185M [00:11<00:00, 16.7MB/s]

# %%
# Load dataset
print("==========================Training Data====================")
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    "potato/Potato/train",
    label_mode="categorical",
    class_names= ['Potato healthy', 'Potato leaf early blight', 'Potato leaf late blight'],
    color_mode="rgb",
    batch_size=1,
    image_size=(256, 256),
    shuffle=True,
    seed=123
)
print("==========================Validation Data====================")
val_data = tf.keras.preprocessing.image_dataset_from_directory(
    "potato/Potato/valid",
    label_mode="categorical",
    class_names= ['Potato healthy', 'Potato leaf early blight', 'Potato leaf late blight'],
    color_mode="rgb",
    batch_size=1,
    image_size=(256, 256),
    shuffle=False,
    seed=123
)
# Out:
# ==========================Training Data====================
# Found 5907 files belonging to 3 classes.
# ==========================Validation Data====================
# Found 1442 files belonging to 3 classes.

# %%
# All images will be rescaled by 1./255.
train_datagen = ImageDataGenerator(rescale = 1.0/256.)
test_datagen  = ImageDataGenerator(rescale = 1.0/256.)

# --------------------
# Flow training images in batches of 20 using train_datagen generator
# --------------------
train_generator = train_datagen.flow_from_directory("potato/Potato/train",
                                                    batch_size=20,
                                                    class_mode='categorical',
                                                    target_size=(224, 224))     
# --------------------
# Flow validation images in batches of 20 using test_datagen generator
# --------------------
validation_generator =  test_datagen.flow_from_directory("potato/Potato/valid",
                                                         batch_size=20,
                                                         class_mode  = 'categorical',
                                                         target_size = (224, 224),
                                                         shuffle=False)
# Out:
# Found 5907 images belonging to 3 classes.
# Found 1442 images belonging to 3 classes.

# %% [markdown]
# Model Non Augmented Evaluating

# %% [markdown]
# Model Dense121 Version 1 Potato Non Augmented

# %%
# load model
import tensorflow as tf
Dense_Non_Aug1 = tf.keras.models.load_model('/content/content/DenseNet_model1_Potato_Based_Non_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Dense_Non_Aug1 = Dense_Non_Aug1.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Dense_Non_Aug1[1]*100))
print("Loss: %.6f%%" % (scores_Dense_Non_Aug1[0]*100))
# Out:
# ==========================Evaluate Model====================
# 73/73 [==============================] - 219s 3s/step - loss: 0.0096 - accuracy: 0.9972
# Accuracy: 99.722606%
# Loss: 0.955558%

# %%
# Confusion Matrix and Classification Report
target_names = ['Potato healthy', 'Potato leaf early blight', 'Potato leaf late blight']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Dense_Non_Aug1.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_potato_dense_non_aug1 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_potato_dense_non_aug1)
# Out:
# ==========================Confusion Matrix====================
# 73/73 [==============================] - 227s 3s/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#           Potato healthy       1.00      1.00      1.00       456
# Potato leaf early blight       0.99      1.00      1.00       493
#  Potato leaf late blight       1.00      0.99      1.00       493
#
#                 accuracy                           1.00      1442
#                macro avg       1.00      1.00      1.00      1442
#             weighted avg       1.00      1.00      1.00      1442
#
# ==========================F1 Score====================
# F1 Score :  0.9972260634829025

# %% [markdown]
# Model Dense121 Version 2 Potato Non Augmented

# %%
# load model
import tensorflow as tf
Dense_Non_Aug2 = tf.keras.models.load_model('/content/content/DenseNet_model2_Potato_Based_Non_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Dense_Non_Aug2 = Dense_Non_Aug2.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Dense_Non_Aug2[1]*100))
print("Loss: %.6f%%" % (scores_Dense_Non_Aug2[0]*100))
# Out:
# ==========================Evaluate Model====================
# 73/73 [==============================] - 224s 3s/step - loss: 0.0063 - accuracy: 0.9972
# Accuracy: 99.722606%
# Loss: 0.631884%

# %%
# Confusion Matrix and Classification Report
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Dense_Non_Aug2.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_potato_dense_non_aug2 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_potato_dense_non_aug2)
# Out:
# ==========================Confusion Matrix====================
# 73/73 [==============================] - 229s 3s/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#           Potato healthy       1.00      1.00      1.00       456
# Potato leaf early blight       0.99      1.00      1.00       493
#  Potato leaf late blight       1.00      0.99      1.00       493
#
#                 accuracy                           1.00      1442
#                macro avg       1.00      1.00      1.00      1442
#             weighted avg       1.00      1.00      1.00      1442
#
# ==========================F1 Score====================
# F1 Score :  0.9972260634829025

# %% [markdown]
# MobileNet V2 Version 1 Potato Non Augmented

# %%
# load model
import tensorflow as tf
Mobile_Non_Aug1 = tf.keras.models.load_model('/content/content/Potato_MobileNetV2_model1_Based_Non_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Mobile_Non_Aug1 = Mobile_Non_Aug1.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Mobile_Non_Aug1[1]*100))
print("Loss: %.6f%%" % (scores_Mobile_Non_Aug1[0]*100))
# Out:
# ==========================Evaluate Model====================
# 73/73 [==============================] - 58s 782ms/step - loss: 0.0162 - accuracy: 0.9951
# Accuracy: 99.514562%
# Loss: 1.622069%

# %%
# Confusion Matrix and Classification Report
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Mobile_Non_Aug1.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_potato_mobile_non_aug1 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_potato_mobile_non_aug1)
# Out:
# ==========================Confusion Matrix====================
# 73/73 [==============================] - 59s 794ms/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#           Potato healthy       1.00      1.00      1.00       456
# Potato leaf early blight       0.99      1.00      0.99       493
#  Potato leaf late blight       1.00      0.99      0.99       493
#
#                 accuracy                           1.00      1442
#                macro avg       1.00      1.00      1.00      1442
#             weighted avg       1.00      1.00      1.00      1442
#
# ==========================F1 Score====================
# F1 Score :  0.9951455861287463

# %% [markdown]
# MobileNet V2 Version 2 Potato Non Augmented

# %%
# load model
import tensorflow as tf
Mobile_Non_Aug2 = tf.keras.models.load_model('/content/content/Potato_MobileNetV2_model2_Based_Non_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Mobile_Non_Aug2 = Mobile_Non_Aug2.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Mobile_Non_Aug2[1]*100))
print("Loss: %.6f%%" % (scores_Mobile_Non_Aug2[0]*100))
# Out:
# ==========================Evaluate Model====================
# 73/73 [==============================] - 56s 756ms/step - loss: 0.0319 - accuracy: 0.9951
# Accuracy: 99.514562%
# Loss: 3.186092%

# %%
# Confusion Matrix and Classification Report
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Mobile_Non_Aug2.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_potato_mobile_non_aug2 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_potato_mobile_non_aug2)
# Out:
# ==========================Confusion Matrix====================
# 73/73 [==============================] - 56s 751ms/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#           Potato healthy       1.00      1.00      1.00       456
# Potato leaf early blight       0.99      0.99      0.99       493
#  Potato leaf late blight       0.99      0.99      0.99       493
#
#                 accuracy                           1.00      1442
#                macro avg       1.00      1.00      1.00      1442
#             weighted avg       1.00      1.00      1.00      1442
#
# ==========================F1 Score====================
# F1 Score :  0.9951456260747561

# %% [markdown]
# Xception Version 1 Potato Non Augmented

# %%
# load model
import tensorflow as tf
Xception_Non_Aug1 = tf.keras.models.load_model('/content/content/Xception_model1_Potato_Based_Non_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Xception_Non_Aug1 = Xception_Non_Aug1.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Xception_Non_Aug1[1]*100))
print("Loss: %.6f%%" % (scores_Xception_Non_Aug1[0]*100))
# Out:
# ==========================Evaluate Model====================
# 73/73 [==============================] - 301s 4s/step - loss: 0.0144 - accuracy: 0.9965
# Accuracy: 99.653262%
# Loss: 1.435050%

# %%
# Confusion Matrix and Classification Report
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Xception_Non_Aug1.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_potato_xception_non_aug1 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_potato_xception_non_aug1)
# Out:
# ==========================Confusion Matrix====================
# 73/73 [==============================] - 298s 4s/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#           Potato healthy       1.00      1.00      1.00       456
# Potato leaf early blight       0.99      1.00      0.99       493
#  Potato leaf late blight       1.00      0.99      0.99       493
#
#                 accuracy                           1.00      1442
#                macro avg       1.00      1.00      1.00      1442
#             weighted avg       1.00      1.00      1.00      1442
#
# ==========================F1 Score====================
# F1 Score :  0.9965325900533973

# %% [markdown]
# Xception Version 2 Potato Non Augmented

# %%
# load model
import tensorflow as tf
Xception_Non_Aug2 = tf.keras.models.load_model('/content/content/Xception_model2_Potato_Based_Non_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Xception_Non_Aug2 = Xception_Non_Aug2.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Xception_Non_Aug2[1]*100))
print("Loss: %.6f%%" % (scores_Xception_Non_Aug2[0]*100))
# Out:
# ==========================Evaluate Model====================
# 73/73 [==============================] - 301s 4s/step - loss: 0.0202 - accuracy: 0.9965
# Accuracy: 99.653262%
# Loss: 2.021545%

# %%
# Confusion Matrix and Classification Report
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Xception_Non_Aug2.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_potato_xception_non_aug2 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_potato_xception_non_aug2)
# Out:
# ==========================Confusion Matrix====================
# 73/73 [==============================] - 296s 4s/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#           Potato healthy       1.00      1.00      1.00       456
# Potato leaf early blight       0.99      1.00      0.99       493
#  Potato leaf late blight       1.00      0.99      0.99       493
#
#                 accuracy                           1.00      1442
#                macro avg       1.00      1.00      1.00      1442
#             weighted avg       1.00      1.00      1.00      1442
#
# ==========================F1 Score====================
# F1 Score :  0.9965325900533973

# %% [markdown]
# Model Augmented Evaluating

# %% [markdown]
# Model Dense121 Version 1 Strawberry Augmented

# %%
# load model
import tensorflow as tf
Dense_Aug1 = tf.keras.models.load_model('/content/content/Potato_DenseNet_model1_Based_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Dense_Aug1 = Dense_Aug1.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Dense_Aug1[1]*100))
print("Loss: %.6f%%" % (scores_Dense_Aug1[0]*100))
# Out:
# ==========================Evaluate Model====================
# 73/73 [==============================] - 222s 3s/step - loss: 0.0157 - accuracy: 0.9965
# Accuracy: 99.653262%
# Loss: 1.568763%

# %%
# Confusion Matrix and Classification Report
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Dense_Aug1.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_potato_dense_aug1 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_potato_dense_aug1)
# Out:
# ==========================Confusion Matrix====================
# 73/73 [==============================] - 235s 3s/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#           Potato healthy       1.00      1.00      1.00       456
# Potato leaf early blight       0.99      1.00      0.99       493
#  Potato leaf late blight       1.00      0.99      0.99       493
#
#                 accuracy                           1.00      1442
#                macro avg       1.00      1.00      1.00      1442
#             weighted avg       1.00      1.00      1.00      1442
#
# ==========================F1 Score====================
# F1 Score :  0.9965325900533973

# %% [markdown]
# Model Dense121 Version 2 Strawberry Augmented

# %%
# load model
import tensorflow as tf
Dense_Aug2 = tf.keras.models.load_model('/content/content/Potato_DenseNet_model2_Based_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Dense_Aug2 = Dense_Aug2.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Dense_Aug2[1]*100))
print("Loss: %.6f%%" % (scores_Dense_Aug2[0]*100))
# Out:
# ==========================Evaluate Model====================
# 73/73 [==============================] - 231s 3s/step - loss: 0.0118 - accuracy: 0.9951
# Accuracy: 99.514562%
# Loss: 1.183714%

# %%
# Confusion Matrix and Classification Report
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Dense_Aug2.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_potato_dense_aug2 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_potato_dense_aug2)
# Out:
# ==========================Confusion Matrix====================
# 73/73 [==============================] - 225s 3s/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#           Potato healthy       1.00      1.00      1.00       456
# Potato leaf early blight       0.99      1.00      0.99       493
#  Potato leaf late blight       1.00      0.99      0.99       493
#
#                 accuracy                           1.00      1442
#                macro avg       1.00      1.00      1.00      1442
#             weighted avg       1.00      1.00      1.00      1442
#
# ==========================F1 Score====================
# F1 Score :  0.9951483844495388

# %% [markdown]
# MobileNet V2 Version 1 Strawberry Augmented

# %%
# Load model
Mobile_Aug1 = tf.keras.models.load_model('/content/content/Potato_MobileNetV2_model1_Based_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Mobile_Aug1 = Mobile_Aug1.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Mobile_Aug1[1]*100))
print("Loss: %.6f%%" % (scores_Mobile_Aug1[0]*100))
# Out:
# ==========================Evaluate Model====================
# 73/73 [==============================] - 57s 765ms/step - loss: 0.0153 - accuracy: 0.9965
# Accuracy: 99.653262%
# Loss: 1.528864%

# %%
# Confusion Matrix and Classification Report
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Mobile_Aug1.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_potato_mobile_aug1 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_potato_mobile_aug1)
# Out:
# ==========================Confusion Matrix====================
# 73/73 [==============================] - 58s 791ms/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#           Potato healthy       1.00      1.00      1.00       456
# Potato leaf early blight       0.99      1.00      1.00       493
#  Potato leaf late blight       1.00      0.99      0.99       493
#
#                 accuracy                           1.00      1442
#                macro avg       1.00      1.00      1.00      1442
#             weighted avg       1.00      1.00      1.00      1442
#
# ==========================F1 Score====================
# F1 Score :  0.9965332605163035

# %% [markdown]
# MobileNet V2 Version 2 Strawberry Augmented

# %%
# Load model
Mobile_Aug2 = tf.keras.models.load_model('/content/content/Potato_MobileNetV2_model2_Based_Augmented')

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_Mobile_Aug2 = Mobile_Aug2.evaluate(validation_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_Mobile_Aug2[1]*100))
print("Loss: %.6f%%" % (scores_Mobile_Aug2[0]*100))
# Out:
# ==========================Evaluate Model====================
# 73/73 [==============================] - 57s 764ms/step - loss: 0.0103 - accuracy: 0.9965
# Accuracy: 99.653262%
# Loss: 1.030148%

# %%
# Confusion Matrix and Classification Report
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = Mobile_Aug2.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(validation_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.show()

print("==========================Classification Report====================")
print('Classification Report')
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# F1 Score
print("==========================F1 Score====================")
f1_potato_mobile_aug2 = f1_score(validation_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_potato_mobile_aug2)
# Out:
# ==========================Confusion Matrix====================
# 73/73 [==============================] - 57s 764ms/step
# ==========================Classification Report====================
# Classification Report
#                           precision    recall  f1-score   support
#
#           Potato healthy       1.00      1.00      1.00       456
# Potato leaf early blight       1.00      0.99      0.99       493
#  Potato leaf late blight       0.99      1.00      0.99       493
#
#                 accuracy                           1.00      1442
#                macro avg       1.00      1.00      1.00      1442
#             weighted avg       1.00      1.00      1.00      1442
#
# ==========================F1 Score====================
# F1 Score :  0.9965325900533973

# %% [markdown]
# Compare All

# %%
# Make dictionary of all models
models = {
    "Dense_Non_Aug1": Dense_Non_Aug1,
    "Dense_Non_Aug2": Dense_Non_Aug2,
    "Mobile_Non_Aug1": Mobile_Non_Aug1,
    "Mobile_Non_Aug2": Mobile_Non_Aug2,
    "Xception_Non_Aug1": Xception_Non_Aug1,
    "Xception_Non_Aug2": Xception_Non_Aug2,
    "Dense_Aug1": Dense_Aug1,
    "Dense_Aug2": Dense_Aug2,
    "Mobile_Aug1": Mobile_Aug1,
    "Mobile_Aug2": Mobile_Aug2,

}

# Make dictionary of all accuracy scores
accuracy = {
    "Dense_Non_Aug1": scores_Dense_Non_Aug1[1],
    "Dense_Non_Aug2": scores_Dense_Non_Aug2[1],
    "Mobile_Non_Aug1": scores_Mobile_Non_Aug1[1],
    "Mobile_Non_Aug2": scores_Mobile_Non_Aug2[1],
    "Xception_Non_Aug1": scores_Xception_Non_Aug1[1],
    "Xception_Non_Aug2": scores_Xception_Non_Aug2[1],
    "Dense_Aug1": scores_Dense_Aug1[1],
    "Dense_Aug2": scores_Dense_Aug2[1],
    "Mobile_Aug1": scores_Mobile_Aug1[1],
    "Mobile_Aug2": scores_Mobile_Aug2[1],


}

# Make dictionary of all loss scores
loss = {
    "Dense_Non_Aug1": scores_Dense_Non_Aug1[0],
    "Dense_Non_Aug2": scores_Dense_Non_Aug2[0],
    "Mobile_Non_Aug1": scores_Mobile_Non_Aug1[0],
    "Mobile_Non_Aug2": scores_Mobile_Non_Aug2[0],
    "Xception_Non_Aug1": scores_Xception_Non_Aug1[0],
    "Xception_Non_Aug2": scores_Xception_Non_Aug2[0],
    "Dense_Aug1": scores_Dense_Aug1[0],
    "Dense_Aug2": scores_Dense_Aug2[0],
    "Mobile_Aug1": scores_Mobile_Aug1[0],
    "Mobile_Aug2": scores_Mobile_Aug2[0],
}

f1 = {
    "Dense_Non_Aug1": f1_potato_dense_non_aug1,
    "Dense_Non_Aug2": f1_potato_dense_non_aug2,
    "Mobile_Non_Aug1": f1_potato_mobile_non_aug1,
    "Mobile_Non_Aug2": f1_potato_mobile_non_aug2,
    "Xception_Non_Aug1": f1_potato_xception_non_aug1,
    "Xception_Non_Aug2": f1_potato_xception_non_aug2,
    "Dense_Aug1": f1_potato_dense_aug1,
    "Dense_Aug2": f1_potato_dense_aug2,
    "Mobile_Aug1": f1_potato_mobile_aug1,
    "Mobile_Aug2": f1_potato_mobile_aug2,
}

# Make dataframe of all models, accuracy, loss, and f1 score
df = pd.DataFrame(list(zip(models.keys(), accuracy.values(), loss.values(), f1.values())), columns =['Model', 'Accuracy', 'Loss', 'F1'])

# Sort dataframe by accuracy
df = df.sort_values(by=['Accuracy'], ascending=False)

# Print dataframe
print(df)
# Out:
#                Model  Accuracy      Loss        F1
# 0     Dense_Non_Aug1  0.997226  0.009556  0.997226
# 1     Dense_Non_Aug2  0.997226  0.006319  0.997226
# 4  Xception_Non_Aug1  0.996533  0.014351  0.996533
# 5  Xception_Non_Aug2  0.996533  0.020215  0.996533
# 6         Dense_Aug1  0.996533  0.015688  0.996533
# 8        Mobile_Aug1  0.996533  0.015289  0.996533
# 9        Mobile_Aug2  0.996533  0.010301  0.996533
# 2    Mobile_Non_Aug1  0.995146  0.016221  0.995146
# 3    Mobile_Non_Aug2  0.995146  0.031861  0.995146
# 7         Dense_Aug2  0.995146  0.011837  0.995148

# %%
# make multiple plots for accuracy, f1 and loss with annotations
# Accuracy
plt.figure(figsize=(20, 10))
plt.title('Accuracy')
plt.bar(df['Model'], df['Accuracy'], color='green')
plt.xticks(rotation=90)
for i, v in enumerate(df['Accuracy']):
    plt.text(i - 0.25, v + 0.01, '{0:.5f}'.format(v))
plt.show()

# F1
plt.figure(figsize=(20, 10))
plt.title('F1')
plt.bar(df['Model'], df['F1'], color='green')
plt.xticks(rotation=90)
for i, v in enumerate(df['F1']):
    plt.text(i - 0.25, v + 0.01, '{0:.5f}'.format(v))
plt.show()

# Loss
plt.figure(figsize=(20, 10))
plt.title('Loss')
plt.bar(df['Model'], df['Loss'], color='green')
plt.xticks(rotation=90)
for i, v in enumerate(df['Loss']):
    plt.text(i - 0.25, v + 0.0001, '{0:.5f}'.format(v))
plt.show()
