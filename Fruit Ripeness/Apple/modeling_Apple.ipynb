# %% [markdown]
# # **Preparations**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

base_dir = '/content/drive/MyDrive/Apple'

print("Contents of base directory:")
print(os.listdir(base_dir))

print("\nContents of train directory:")
print(os.listdir(f'{base_dir}/train'))

print("\nContents of validation directory:")
print(os.listdir(f'{base_dir}/valid'))
# Out:
# Contents of base directory:
# ['train', 'valid']
#
# Contents of train directory:
# ['good', 'bad']
#
# Contents of validation directory:
# ['good', 'bad']

# %%
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'valid')

# Directory with training pictures
train_bad_dir = os.path.join(train_dir, 'bad')
train_good_dir = os.path.join(train_dir, 'good')

# Directory with validation pictures
validation_bad_dir = os.path.join(validation_dir, 'bad')
validation_good_dir = os.path.join(validation_dir, 'good')

# %%
train_bad_fnames = os.listdir(train_bad_dir)
train_good_fnames = os.listdir(train_good_dir)

print(train_bad_fnames[:10])
print(train_good_fnames[:10])
# Out:
# ['IMG20200728175908.jpg', 'IMG20200728175909.jpg', 'IMG20200728175856.jpg', 'IMG20200728175907.jpg', 'IMG20200728175922.jpg', 'IMG20200728175910.jpg', 'IMG20200728175927.jpg', 'IMG20200728175919.jpg', 'IMG20200728175917.jpg', 'IMG20200728175912.jpg']
# ['20190809_115448.jpg', '20190809_115459.jpg', '20190809_115451.jpg', '20190809_115527.jpg', '20190809_115505.jpg', '20190809_115534.jpg', '20190809_115547.jpg', '20190809_115602.jpg', '20190809_115613.jpg', '20190809_115606.jpg']

# %%
print('total training `bad` images:', len(os.listdir(train_bad_dir)))
print('total training `good` images:', len(os.listdir(train_good_dir)))

print('total validation `bad` images:', len(os.listdir(validation_bad_dir)))
print('total validation `good` images:', len(os.listdir(validation_good_dir)))
# Out:
# total training `bad` images: 902
# total training `good` images: 912
# total validation `bad` images: 117
# total validation `good` images: 120

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

nrows = 4
ncols = 4

pic_index = 0

# %%
fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

pic_index += 8

next_bad_pix = [os.path.join(train_bad_dir, fname) 
                for fname in train_bad_fnames[pic_index-8 : pic_index] 
               ]

next_good_pix = [os.path.join(train_good_dir, fname) 
                for fname in train_good_fnames[ pic_index-8 : pic_index]
               ]

for i, img_path in enumerate(next_bad_pix + next_good_pix):
  sp = plt.subplot(nrows, ncols, i+1)
  sp.axis('Off')
  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
from google.colab import files

# %% [markdown]
# # **Self-Created Model Arch with Non-Augmented Data & No Callback(s)**

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])

# %%
model.summary()

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255.)
test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(150, 150))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(150, 150))

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator
    )

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Self-Created Model Arch with Non-Augmented Data & No Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Self-Created Model Arch with Non-Augmented Data & No Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # **Self-Created Model Arch with Augmented Data & Callback(s)**

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])

# %%
model.summary()

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=80,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(150, 150))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(150, 150))

# %%
# Defining Callbacks

# Save the best model
file_path = '/content/checkpoint/self_created'
checkpoint_callback = ModelCheckpoint(filepath=file_path, save_best_only=True, monitor='val_accuracy', verbose=2)

# Early stopping
early_stopping_callback = EarlyStopping(monitor='val_accuracy', patience=10, verbose=2, restore_best_weights=True)

# Reduce learning rate
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=2, min_lr=1e-6)

callbacks=[checkpoint_callback, early_stopping_callback, reduce_lr_callback]

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=callbacks
    )

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Self-Created Model Arch with Augmented Data & Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Self-Created Model Arch with Augmented Data & Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # **Transfer Learning (Xception) with Augmented Data & Callback(s)**

# %%
from tensorflow.keras.applications import Xception

# %%
model = tf.keras.models.Sequential([
    # Xception Layer
    Xception(include_top=False, weights='imagenet', input_shape=(224, 224, 3)),
    # Max Pooling Layer
    tf.keras.layers.GlobalMaxPooling2D(),
    # Drop Out Layer
    tf.keras.layers.Dropout(0.2),
    # 256 neuron hidden layer
    tf.keras.layers.Dense(256, activation='relu'),
    # Output
    tf.keras.layers.Dense(2, activation='softmax') 
])

model.layers[0].trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 5s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  global_max_pooling2d (Globa  (None, 2048)             0
#  lMaxPooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 21,386,538
# Trainable params: 525,058
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=80,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(224, 224))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(224, 224))
# Out:
# Found 1814 images belonging to 2 classes.
# Found 237 images belonging to 2 classes.

# %%
# Defining Callbacks

# Save the best model
file_path = '/content/checkpoint/xception'
checkpoint_callback = ModelCheckpoint(filepath=file_path, save_best_only=True, monitor='val_accuracy', verbose=2)

# Early stopping
early_stopping_callback = EarlyStopping(monitor='val_accuracy', patience=10, verbose=2, restore_best_weights=True)

# Reduce learning rate
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=2, min_lr=1e-6)

callbacks=[checkpoint_callback, early_stopping_callback, reduce_lr_callback]

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=callbacks
    )
# Out:
# Epoch 1/50
# 57/57 [==============================] - ETA: 0s - loss: 0.5838 - accuracy: 0.8479
# Epoch 1: val_accuracy improved from -inf to 0.96203, saving model to /content/checkpoint/xception
# 57/57 [==============================] - 893s 15s/step - loss: 0.5838 - accuracy: 0.8479 - val_loss: 0.0927 - val_accuracy: 0.9620 - lr: 0.0010
# Epoch 2/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0960 - accuracy: 0.9631
# Epoch 2: val_accuracy improved from 0.96203 to 0.97046, saving model to /content/checkpoint/xception
# 57/57 [==============================] - 50s 885ms/step - loss: 0.0960 - accuracy: 0.9631 - val_loss: 0.1010 - val_accuracy: 0.9705 - lr: 0.0010
# Epoch 3/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0900 - accuracy: 0.9691
# Epoch 3: val_accuracy did not improve from 0.97046
# 57/57 [==============================] - 30s 521ms/step - loss: 0.0900 - accuracy: 0.9691 - val_loss: 0.0762 - val_accuracy: 0.9662 - lr: 0.0010
# Epoch 4/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0752 - accuracy: 0.9708
# Epoch 4: val_accuracy improved from 0.97046 to 0.97468, saving model to /content/checkpoint/xception
# 57/57 [==============================] - 48s 849ms/step - loss: 0.0752 - accuracy: 0.9708 - val_loss: 0.0630 - val_accuracy: 0.9747 - lr: 0.0010
# Epoch 5/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0673 - accuracy: 0.9746
# Epoch 5: val_accuracy did not improve from 0.97468
# 57/57 [==============================] - 29s 512ms/step - loss: 0.0673 - accuracy: 0.9746 - val_loss: 0.0571 - val_accuracy: 0.9747 - lr: 0.0010
# Epoch 6/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0684 - accuracy: 0.9779
# Epoch 6: val_accuracy did not improve from 0.97468
# 57/57 [==============================] - 29s 514ms/step - loss: 0.0684 - accuracy: 0.9779 - val_loss: 0.0757 - val_accuracy: 0.9705 - lr: 0.0010
# Epoch 7/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0558 - accuracy: 0.9768
# Epoch 7: val_accuracy improved from 0.97468 to 0.98734, saving model to /content/checkpoint/xception
# 57/57 [==============================] - 50s 890ms/step - loss: 0.0558 - accuracy: 0.9768 - val_loss: 0.0446 - val_accuracy: 0.9873 - lr: 0.0010
# Epoch 8/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0548 - accuracy: 0.9785
# Epoch 8: val_accuracy did not improve from 0.98734
# 57/57 [==============================] - 30s 525ms/step - loss: 0.0548 - accuracy: 0.9785 - val_loss: 0.0501 - val_accuracy: 0.9789 - lr: 0.0010
# Epoch 9/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0422 - accuracy: 0.9846
# Epoch 9: val_accuracy did not improve from 0.98734
# 57/57 [==============================] - 30s 537ms/step - loss: 0.0422 - accuracy: 0.9846 - val_loss: 0.0382 - val_accuracy: 0.9873 - lr: 0.0010
# Epoch 10/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0698 - accuracy: 0.9735
# Epoch 10: val_accuracy did not improve from 0.98734
# 57/57 [==============================] - 30s 518ms/step - loss: 0.0698 - accuracy: 0.9735 - val_loss: 0.0629 - val_accuracy: 0.9747 - lr: 0.0010
# Epoch 11/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9824
# Epoch 11: val_accuracy did not improve from 0.98734
# 57/57 [==============================] - 31s 547ms/step - loss: 0.0404 - accuracy: 0.9824 - val_loss: 0.0243 - val_accuracy: 0.9873 - lr: 0.0010
# Epoch 12/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 0.9768
# Epoch 12: val_accuracy did not improve from 0.98734
# 57/57 [==============================] - 29s 515ms/step - loss: 0.0506 - accuracy: 0.9768 - val_loss: 0.0791 - val_accuracy: 0.9620 - lr: 0.0010
# Epoch 13/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9895
# Epoch 13: val_accuracy did not improve from 0.98734
# 57/57 [==============================] - 30s 519ms/step - loss: 0.0263 - accuracy: 0.9895 - val_loss: 0.0469 - val_accuracy: 0.9789 - lr: 0.0010
# Epoch 14/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0292 - accuracy: 0.9890
# Epoch 14: val_accuracy did not improve from 0.98734
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 57/57 [==============================] - 30s 523ms/step - loss: 0.0292 - accuracy: 0.9890 - val_loss: 0.0442 - val_accuracy: 0.9789 - lr: 0.0010
# Epoch 15/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0292 - accuracy: 0.9879
# Epoch 15: val_accuracy improved from 0.98734 to 0.99156, saving model to /content/checkpoint/xception
# 57/57 [==============================] - 49s 865ms/step - loss: 0.0292 - accuracy: 0.9879 - val_loss: 0.0292 - val_accuracy: 0.9916 - lr: 1.0000e-04
# Epoch 16/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0396 - accuracy: 0.9851
# Epoch 16: val_accuracy did not improve from 0.99156
# 57/57 [==============================] - 30s 519ms/step - loss: 0.0396 - accuracy: 0.9851 - val_loss: 0.0272 - val_accuracy: 0.9916 - lr: 1.0000e-04
# Epoch 17/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9917
# Epoch 17: val_accuracy did not improve from 0.99156
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 57/57 [==============================] - 29s 515ms/step - loss: 0.0211 - accuracy: 0.9917 - val_loss: 0.0263 - val_accuracy: 0.9916 - lr: 1.0000e-04
# Epoch 18/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9873
# Epoch 18: val_accuracy did not improve from 0.99156
# 57/57 [==============================] - 31s 542ms/step - loss: 0.0332 - accuracy: 0.9873 - val_loss: 0.0260 - val_accuracy: 0.9916 - lr: 1.0000e-05
# Epoch 19/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9890
# Epoch 19: val_accuracy did not improve from 0.99156
# 57/57 [==============================] - 30s 521ms/step - loss: 0.0281 - accuracy: 0.9890 - val_loss: 0.0265 - val_accuracy: 0.9916 - lr: 1.0000e-05
# Epoch 20/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9868
# Epoch 20: val_accuracy did not improve from 0.99156
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 57/57 [==============================] - 30s 518ms/step - loss: 0.0326 - accuracy: 0.9868 - val_loss: 0.0268 - val_accuracy: 0.9916 - lr: 1.0000e-05
# Epoch 21/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9884
# Epoch 21: val_accuracy did not improve from 0.99156
# 57/57 [==============================] - 30s 523ms/step - loss: 0.0277 - accuracy: 0.9884 - val_loss: 0.0267 - val_accuracy: 0.9916 - lr: 1.0000e-06
# Epoch 22/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9879
# Epoch 22: val_accuracy did not improve from 0.99156
# 57/57 [==============================] - 29s 516ms/step - loss: 0.0331 - accuracy: 0.9879 - val_loss: 0.0266 - val_accuracy: 0.9916 - lr: 1.0000e-06
# Epoch 23/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9873
# Epoch 23: val_accuracy did not improve from 0.99156
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1e-06.
# 57/57 [==============================] - 29s 512ms/step - loss: 0.0346 - accuracy: 0.9873 - val_loss: 0.0266 - val_accuracy: 0.9916 - lr: 1.0000e-06
# Epoch 24/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9895
# Epoch 24: val_accuracy did not improve from 0.99156
# 57/57 [==============================] - 29s 514ms/step - loss: 0.0247 - accuracy: 0.9895 - val_loss: 0.0267 - val_accuracy: 0.9916 - lr: 1.0000e-06
# Epoch 25/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9912
# Epoch 25: val_accuracy did not improve from 0.99156
# Restoring model weights from the end of the best epoch: 15.
# 57/57 [==============================] - 30s 525ms/step - loss: 0.0275 - accuracy: 0.9912 - val_loss: 0.0267 - val_accuracy: 0.9916 - lr: 1.0000e-06
# Epoch 25: early stopping

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Transfer Learning (Xception) with Augmented Data & Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Transfer Learning (Xception) with Augmented Data & Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# !zip -r /content/apple_xception.zip /content/checkpoint/xception
# Out:
#   adding: content/checkpoint/xception/ (stored 0%)
#   adding: content/checkpoint/xception/variables/ (stored 0%)
#   adding: content/checkpoint/xception/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: content/checkpoint/xception/variables/variables.index (deflated 76%)
#   adding: content/checkpoint/xception/assets/ (stored 0%)
#   adding: content/checkpoint/xception/fingerprint.pb (stored 0%)
#   adding: content/checkpoint/xception/saved_model.pb (deflated 92%)
#   adding: content/checkpoint/xception/keras_metadata.pb (deflated 96%)

# %%
files.download("/content/apple_xception.zip")

# %% [markdown]
# # **Transfer Learning (MobileNetV2) with Augmented Data & Callback(s)**

# %%
from tensorflow.keras.applications import MobileNetV2

# %%
model = tf.keras.models.Sequential([
    # MobileNetV2 Layer
    MobileNetV2(include_top=False, weights='imagenet', input_shape=(224, 224, 3)),
    # Max Pooling Layer
    tf.keras.layers.GlobalMaxPooling2D(),
    # Drop Out Layer
    tf.keras.layers.Dropout(0.2),
    # 256 neuron hidden layer
    tf.keras.layers.Dense(256, activation='relu'),
    # Output
    tf.keras.layers.Dense(2, activation='softmax') 
])

model.layers[0].trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 2s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_max_pooling2d_1 (Glo  (None, 1280)             0
#  balMaxPooling2D)
#
#  dropout_1 (Dropout)         (None, 1280)              0
#
#  dense_2 (Dense)             (None, 256)               327936
#
#  dense_3 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 2,586,434
# Trainable params: 328,450
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=80,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(224, 224))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(224, 224))
# Out:
# Found 1814 images belonging to 2 classes.
# Found 237 images belonging to 2 classes.

# %%
# Defining Callbacks

# Save the best model
file_path = '/content/checkpoint/mobilenetv2'
checkpoint_callback = ModelCheckpoint(filepath=file_path, save_best_only=True, monitor='val_accuracy', verbose=2)

# Early stopping
early_stopping_callback = EarlyStopping(monitor='val_accuracy', patience=10, verbose=2, restore_best_weights=True)

# Reduce learning rate
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=2, min_lr=1e-6)

callbacks=[checkpoint_callback, early_stopping_callback, reduce_lr_callback]

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=callbacks
    )
# Out:
# Epoch 1/50
# 57/57 [==============================] - ETA: 0s - loss: 1.3253 - accuracy: 0.8286
# Epoch 1: val_accuracy improved from -inf to 0.93671, saving model to /content/checkpoint/mobilenetv2
# 57/57 [==============================] - 54s 894ms/step - loss: 1.3253 - accuracy: 0.8286 - val_loss: 0.1388 - val_accuracy: 0.9367 - lr: 0.0010
# Epoch 2/50
# 57/57 [==============================] - ETA: 0s - loss: 0.1252 - accuracy: 0.9526
# Epoch 2: val_accuracy improved from 0.93671 to 0.97046, saving model to /content/checkpoint/mobilenetv2
# 57/57 [==============================] - 50s 876ms/step - loss: 0.1252 - accuracy: 0.9526 - val_loss: 0.0686 - val_accuracy: 0.9705 - lr: 0.0010
# Epoch 3/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0930 - accuracy: 0.9636
# Epoch 3: val_accuracy improved from 0.97046 to 0.97890, saving model to /content/checkpoint/mobilenetv2
# 57/57 [==============================] - 49s 867ms/step - loss: 0.0930 - accuracy: 0.9636 - val_loss: 0.0633 - val_accuracy: 0.9789 - lr: 0.0010
# Epoch 4/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0786 - accuracy: 0.9708
# Epoch 4: val_accuracy did not improve from 0.97890
# 57/57 [==============================] - 28s 494ms/step - loss: 0.0786 - accuracy: 0.9708 - val_loss: 0.1112 - val_accuracy: 0.9662 - lr: 0.0010
# Epoch 5/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0880 - accuracy: 0.9680
# Epoch 5: val_accuracy did not improve from 0.97890
# 57/57 [==============================] - 28s 493ms/step - loss: 0.0880 - accuracy: 0.9680 - val_loss: 0.0677 - val_accuracy: 0.9747 - lr: 0.0010
# Epoch 6/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0666 - accuracy: 0.9768
# Epoch 6: val_accuracy improved from 0.97890 to 0.98734, saving model to /content/checkpoint/mobilenetv2
# 57/57 [==============================] - 49s 868ms/step - loss: 0.0666 - accuracy: 0.9768 - val_loss: 0.0317 - val_accuracy: 0.9873 - lr: 0.0010
# Epoch 7/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0795 - accuracy: 0.9708
# Epoch 7: val_accuracy improved from 0.98734 to 0.99156, saving model to /content/checkpoint/mobilenetv2
# 57/57 [==============================] - 50s 886ms/step - loss: 0.0795 - accuracy: 0.9708 - val_loss: 0.0249 - val_accuracy: 0.9916 - lr: 0.0010
# Epoch 8/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0471 - accuracy: 0.9824
# Epoch 8: val_accuracy did not improve from 0.99156
# 57/57 [==============================] - 28s 495ms/step - loss: 0.0471 - accuracy: 0.9824 - val_loss: 0.0260 - val_accuracy: 0.9916 - lr: 0.0010
# Epoch 9/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0505 - accuracy: 0.9818
# Epoch 9: val_accuracy did not improve from 0.99156
# 57/57 [==============================] - 29s 502ms/step - loss: 0.0505 - accuracy: 0.9818 - val_loss: 0.0348 - val_accuracy: 0.9831 - lr: 0.0010
# Epoch 10/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 0.9846
# Epoch 10: val_accuracy did not improve from 0.99156
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 57/57 [==============================] - 28s 489ms/step - loss: 0.0480 - accuracy: 0.9846 - val_loss: 0.0480 - val_accuracy: 0.9789 - lr: 0.0010
# Epoch 11/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0382 - accuracy: 0.9868
# Epoch 11: val_accuracy did not improve from 0.99156
# 57/57 [==============================] - 29s 506ms/step - loss: 0.0382 - accuracy: 0.9868 - val_loss: 0.0320 - val_accuracy: 0.9831 - lr: 1.0000e-04
# Epoch 12/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9906
# Epoch 12: val_accuracy did not improve from 0.99156
# 57/57 [==============================] - 27s 477ms/step - loss: 0.0239 - accuracy: 0.9906 - val_loss: 0.0275 - val_accuracy: 0.9916 - lr: 1.0000e-04
# Epoch 13/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0337 - accuracy: 0.9879
# Epoch 13: val_accuracy did not improve from 0.99156
# 57/57 [==============================] - 29s 498ms/step - loss: 0.0337 - accuracy: 0.9879 - val_loss: 0.0221 - val_accuracy: 0.9916 - lr: 1.0000e-04
# Epoch 14/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9906
# Epoch 14: val_accuracy improved from 0.99156 to 0.99578, saving model to /content/checkpoint/mobilenetv2
# 57/57 [==============================] - 49s 857ms/step - loss: 0.0301 - accuracy: 0.9906 - val_loss: 0.0181 - val_accuracy: 0.9958 - lr: 1.0000e-04
# Epoch 15/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9923
# Epoch 15: val_accuracy did not improve from 0.99578
# 57/57 [==============================] - 30s 524ms/step - loss: 0.0275 - accuracy: 0.9923 - val_loss: 0.0185 - val_accuracy: 0.9958 - lr: 1.0000e-04
# Epoch 16/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9901
# Epoch 16: val_accuracy did not improve from 0.99578
# 57/57 [==============================] - 28s 495ms/step - loss: 0.0230 - accuracy: 0.9901 - val_loss: 0.0257 - val_accuracy: 0.9873 - lr: 1.0000e-04
# Epoch 17/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9923
# Epoch 17: val_accuracy did not improve from 0.99578
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 57/57 [==============================] - 28s 493ms/step - loss: 0.0237 - accuracy: 0.9923 - val_loss: 0.0190 - val_accuracy: 0.9958 - lr: 1.0000e-04
# Epoch 18/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9906
# Epoch 18: val_accuracy did not improve from 0.99578
# 57/57 [==============================] - 28s 500ms/step - loss: 0.0298 - accuracy: 0.9906 - val_loss: 0.0187 - val_accuracy: 0.9958 - lr: 1.0000e-05
# Epoch 19/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9912
# Epoch 19: val_accuracy did not improve from 0.99578
# 57/57 [==============================] - 30s 519ms/step - loss: 0.0230 - accuracy: 0.9912 - val_loss: 0.0185 - val_accuracy: 0.9958 - lr: 1.0000e-05
# Epoch 20/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9862
# Epoch 20: val_accuracy did not improve from 0.99578
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 57/57 [==============================] - 28s 494ms/step - loss: 0.0387 - accuracy: 0.9862 - val_loss: 0.0193 - val_accuracy: 0.9958 - lr: 1.0000e-05
# Epoch 21/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0296 - accuracy: 0.9901
# Epoch 21: val_accuracy did not improve from 0.99578
# 57/57 [==============================] - 28s 494ms/step - loss: 0.0296 - accuracy: 0.9901 - val_loss: 0.0194 - val_accuracy: 0.9958 - lr: 1.0000e-06
# Epoch 22/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 0.9890
# Epoch 22: val_accuracy did not improve from 0.99578
# 57/57 [==============================] - 28s 496ms/step - loss: 0.0248 - accuracy: 0.9890 - val_loss: 0.0195 - val_accuracy: 0.9958 - lr: 1.0000e-06
# Epoch 23/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9901
# Epoch 23: val_accuracy did not improve from 0.99578
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1e-06.
# 57/57 [==============================] - 28s 490ms/step - loss: 0.0283 - accuracy: 0.9901 - val_loss: 0.0196 - val_accuracy: 0.9958 - lr: 1.0000e-06
# Epoch 24/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9890
# Epoch 24: val_accuracy did not improve from 0.99578
# Restoring model weights from the end of the best epoch: 14.
# 57/57 [==============================] - 30s 529ms/step - loss: 0.0237 - accuracy: 0.9890 - val_loss: 0.0197 - val_accuracy: 0.9958 - lr: 1.0000e-06
# Epoch 24: early stopping

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Transfer Learning (MobileNetV2) with Augmented Data & Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Transfer Learning (MobileNetV2) with Augmented Data & Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# !zip -r /content/apple_mobilenetv2.zip /content/checkpoint/mobilenetv2
# Out:
#   adding: content/checkpoint/mobilenetv2/ (stored 0%)
#   adding: content/checkpoint/mobilenetv2/variables/ (stored 0%)
#   adding: content/checkpoint/mobilenetv2/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: content/checkpoint/mobilenetv2/variables/variables.index (deflated 76%)
#   adding: content/checkpoint/mobilenetv2/assets/ (stored 0%)
#   adding: content/checkpoint/mobilenetv2/fingerprint.pb (stored 0%)
#   adding: content/checkpoint/mobilenetv2/saved_model.pb (deflated 91%)
#   adding: content/checkpoint/mobilenetv2/keras_metadata.pb (deflated 96%)

# %%
files.download("/content/apple_mobilenetv2.zip")

# %% [markdown]
# # **Transfer Learning (Densenet121) with Augmented Data & Callback(s)**

# %%
from tensorflow.keras.applications import DenseNet121

# %%
model = tf.keras.models.Sequential([
    # DenseNet121 Layer
    DenseNet121(include_top=False, weights='imagenet', input_shape=(224, 224, 3)),
    # Max Pooling Layer
    tf.keras.layers.GlobalMaxPooling2D(),
    # Drop Out Layer
    tf.keras.layers.Dropout(0.2),
    # 256 neuron hidden layer
    tf.keras.layers.Dense(256, activation='relu'),
    # Output
    tf.keras.layers.Dense(2, activation='softmax') 
])

model.layers[0].trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet121 (Functional)    (None, 7, 7, 1024)        7037504
#
#  global_max_pooling2d_2 (Glo  (None, 1024)             0
#  balMaxPooling2D)
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 256)               262400
#
#  dense_5 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 7,300,418
# Trainable params: 262,914
# Non-trainable params: 7,037,504
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=80,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(224, 224))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(224, 224))
# Out:
# Found 1814 images belonging to 2 classes.
# Found 237 images belonging to 2 classes.

# %%
# Defining Callbacks

# Save the best model
file_path = '/content/checkpoint/densenet121'
checkpoint_callback = ModelCheckpoint(filepath=file_path, save_best_only=True, monitor='val_accuracy', verbose=2)

# Early stopping
early_stopping_callback = EarlyStopping(monitor='val_accuracy', patience=10, verbose=2, restore_best_weights=True)

# Reduce learning rate
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=2, min_lr=1e-6)

callbacks=[checkpoint_callback, early_stopping_callback, reduce_lr_callback]

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=callbacks
    )
# Out:
# Epoch 1/50
# 57/57 [==============================] - ETA: 0s - loss: 0.9610 - accuracy: 0.8517
# Epoch 1: val_accuracy improved from -inf to 0.96624, saving model to /content/checkpoint/densenet121
# 57/57 [==============================] - 96s 2s/step - loss: 0.9610 - accuracy: 0.8517 - val_loss: 0.0875 - val_accuracy: 0.9662 - lr: 0.0010
# Epoch 2/50
# 57/57 [==============================] - ETA: 0s - loss: 0.1290 - accuracy: 0.9553
# Epoch 2: val_accuracy improved from 0.96624 to 0.97890, saving model to /content/checkpoint/densenet121
# 57/57 [==============================] - 81s 1s/step - loss: 0.1290 - accuracy: 0.9553 - val_loss: 0.0364 - val_accuracy: 0.9789 - lr: 0.0010
# Epoch 3/50
# 57/57 [==============================] - ETA: 0s - loss: 0.1236 - accuracy: 0.9598
# Epoch 3: val_accuracy did not improve from 0.97890
# 57/57 [==============================] - 30s 522ms/step - loss: 0.1236 - accuracy: 0.9598 - val_loss: 0.0600 - val_accuracy: 0.9747 - lr: 0.0010
# Epoch 4/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0776 - accuracy: 0.9713
# Epoch 4: val_accuracy improved from 0.97890 to 0.98312, saving model to /content/checkpoint/densenet121
# 57/57 [==============================] - 82s 1s/step - loss: 0.0776 - accuracy: 0.9713 - val_loss: 0.0682 - val_accuracy: 0.9831 - lr: 0.0010
# Epoch 5/50
# 57/57 [==============================] - ETA: 0s - loss: 0.1030 - accuracy: 0.9680
# Epoch 5: val_accuracy improved from 0.98312 to 0.98734, saving model to /content/checkpoint/densenet121
# 57/57 [==============================] - 82s 1s/step - loss: 0.1030 - accuracy: 0.9680 - val_loss: 0.0232 - val_accuracy: 0.9873 - lr: 0.0010
# Epoch 6/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0682 - accuracy: 0.9785
# Epoch 6: val_accuracy did not improve from 0.98734
# 57/57 [==============================] - 30s 526ms/step - loss: 0.0682 - accuracy: 0.9785 - val_loss: 0.0398 - val_accuracy: 0.9831 - lr: 0.0010
# Epoch 7/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9813
# Epoch 7: val_accuracy did not improve from 0.98734
# 57/57 [==============================] - 30s 519ms/step - loss: 0.0479 - accuracy: 0.9813 - val_loss: 0.0421 - val_accuracy: 0.9831 - lr: 0.0010
# Epoch 8/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9669
# Epoch 8: val_accuracy did not improve from 0.98734
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 57/57 [==============================] - 30s 522ms/step - loss: 0.0858 - accuracy: 0.9669 - val_loss: 0.1200 - val_accuracy: 0.9536 - lr: 0.0010
# Epoch 9/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0745 - accuracy: 0.9713
# Epoch 9: val_accuracy improved from 0.98734 to 0.99156, saving model to /content/checkpoint/densenet121
# 57/57 [==============================] - 83s 1s/step - loss: 0.0745 - accuracy: 0.9713 - val_loss: 0.0275 - val_accuracy: 0.9916 - lr: 1.0000e-04
# Epoch 10/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 0.9884
# Epoch 10: val_accuracy did not improve from 0.99156
# 57/57 [==============================] - 29s 515ms/step - loss: 0.0412 - accuracy: 0.9884 - val_loss: 0.0236 - val_accuracy: 0.9916 - lr: 1.0000e-04
# Epoch 11/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9846
# Epoch 11: val_accuracy did not improve from 0.99156
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 57/57 [==============================] - 30s 519ms/step - loss: 0.0540 - accuracy: 0.9846 - val_loss: 0.0233 - val_accuracy: 0.9916 - lr: 1.0000e-04
# Epoch 12/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9857
# Epoch 12: val_accuracy did not improve from 0.99156
# 57/57 [==============================] - 30s 535ms/step - loss: 0.0474 - accuracy: 0.9857 - val_loss: 0.0222 - val_accuracy: 0.9916 - lr: 1.0000e-05
# Epoch 13/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9785
# Epoch 13: val_accuracy did not improve from 0.99156
# 57/57 [==============================] - 30s 518ms/step - loss: 0.0642 - accuracy: 0.9785 - val_loss: 0.0203 - val_accuracy: 0.9916 - lr: 1.0000e-05
# Epoch 14/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0461 - accuracy: 0.9835
# Epoch 14: val_accuracy did not improve from 0.99156
# 57/57 [==============================] - 30s 519ms/step - loss: 0.0461 - accuracy: 0.9835 - val_loss: 0.0201 - val_accuracy: 0.9916 - lr: 1.0000e-05
# Epoch 15/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0345 - accuracy: 0.9873
# Epoch 15: val_accuracy did not improve from 0.99156
# 57/57 [==============================] - 30s 525ms/step - loss: 0.0345 - accuracy: 0.9873 - val_loss: 0.0206 - val_accuracy: 0.9916 - lr: 1.0000e-05
# Epoch 16/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9840
# Epoch 16: val_accuracy did not improve from 0.99156
# 57/57 [==============================] - 31s 540ms/step - loss: 0.0555 - accuracy: 0.9840 - val_loss: 0.0212 - val_accuracy: 0.9916 - lr: 1.0000e-05
# Epoch 17/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0595 - accuracy: 0.9791
# Epoch 17: val_accuracy did not improve from 0.99156
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 57/57 [==============================] - 31s 545ms/step - loss: 0.0595 - accuracy: 0.9791 - val_loss: 0.0206 - val_accuracy: 0.9916 - lr: 1.0000e-05
# Epoch 18/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0339 - accuracy: 0.9851
# Epoch 18: val_accuracy did not improve from 0.99156
# 57/57 [==============================] - 29s 513ms/step - loss: 0.0339 - accuracy: 0.9851 - val_loss: 0.0206 - val_accuracy: 0.9916 - lr: 1.0000e-06
# Epoch 19/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0437 - accuracy: 0.9818
# Epoch 19: val_accuracy did not improve from 0.99156
# Restoring model weights from the end of the best epoch: 9.
# 57/57 [==============================] - 30s 522ms/step - loss: 0.0437 - accuracy: 0.9818 - val_loss: 0.0204 - val_accuracy: 0.9916 - lr: 1.0000e-06
# Epoch 19: early stopping

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Transfer Learning (DenseNet121) with Augmented Data & Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Transfer Learning (DenseNet121) with Augmented Data & Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# !zip -r /content/apple_densenet121.zip /content/checkpoint/densenet121
# Out:
#   adding: content/checkpoint/densenet121/ (stored 0%)
#   adding: content/checkpoint/densenet121/variables/ (stored 0%)
#   adding: content/checkpoint/densenet121/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: content/checkpoint/densenet121/variables/variables.index (deflated 78%)
#   adding: content/checkpoint/densenet121/assets/ (stored 0%)
#   adding: content/checkpoint/densenet121/fingerprint.pb (stored 0%)
#   adding: content/checkpoint/densenet121/saved_model.pb (deflated 92%)
#   adding: content/checkpoint/densenet121/keras_metadata.pb (deflated 96%)

# %%
files.download("/content/apple_densenet121.zip")
