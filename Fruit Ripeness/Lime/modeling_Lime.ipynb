# %% [markdown]
# # **Preparations**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

base_dir = '/content/drive/MyDrive/Lime'

print("Contents of base directory:")
print(os.listdir(base_dir))

print("\nContents of train directory:")
print(os.listdir(f'{base_dir}/train'))

print("\nContents of validation directory:")
print(os.listdir(f'{base_dir}/valid'))
# Out:
# Contents of base directory:
# ['train', 'valid']
#
# Contents of train directory:
# ['bad', 'good']
#
# Contents of validation directory:
# ['bad', 'good']

# %%
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'valid')

# Directory with training pictures
train_bad_dir = os.path.join(train_dir, 'bad')
train_good_dir = os.path.join(train_dir, 'good')

# Directory with validation pictures
validation_bad_dir = os.path.join(validation_dir, 'bad')
validation_good_dir = os.path.join(validation_dir, 'good')

# %%
train_bad_fnames = os.listdir(train_bad_dir)
train_good_fnames = os.listdir(train_good_dir)

print(train_bad_fnames[:10])
print(train_good_fnames[:10])
# Out:
# ['IMG20200728190811.jpg', 'IMG20200728190810.jpg', 'IMG20200728190823.jpg', 'IMG20200728190813.jpg', 'IMG20200728190814.jpg', 'IMG20200728190828.jpg', 'IMG20200728190824.jpg', 'IMG20200728190815.jpg', 'IMG20200728190826.jpg', 'IMG20200728190812.jpg']
# ['IMG20200728191219.jpg', 'IMG20200728191219_01.jpg', 'IMG20200728191222.jpg', 'IMG20200728191226.jpg', 'IMG20200728191221_01.jpg', 'IMG20200728191225.jpg', 'IMG20200728191221.jpg', 'IMG20200728191223.jpg', 'IMG20200728191220.jpg', 'IMG20200728191224.jpg']

# %%
print('total training `bad` images:', len(os.listdir(train_bad_dir)))
print('total training `good` images:', len(os.listdir(train_good_dir)))

print('total validation `bad` images:', len(os.listdir(validation_bad_dir)))
print('total validation `good` images:', len(os.listdir(validation_good_dir)))
# Out:
# total training `bad` images: 535
# total training `good` images: 481
# total validation `bad` images: 97
# total validation `good` images: 77

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

nrows = 4
ncols = 4

pic_index = 0

# %%
fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

pic_index += 8

next_bad_pix = [os.path.join(train_bad_dir, fname) 
                for fname in train_bad_fnames[pic_index-8 : pic_index] 
               ]

next_good_pix = [os.path.join(train_good_dir, fname) 
                for fname in train_good_fnames[ pic_index-8 : pic_index]
               ]

for i, img_path in enumerate(next_bad_pix + next_good_pix):
  sp = plt.subplot(nrows, ncols, i+1)
  sp.axis('Off')
  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
from google.colab import files

# %% [markdown]
# # **Self-Created Model Arch with Non-Augmented Data & No Callback(s)**

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])

# %%
model.summary()

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255.)
test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(150, 150))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(150, 150))

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator
    )

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Self-Created Model Arch with Non-Augmented Data & No Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Self-Created Model Arch with Non-Augmented Data & No Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # **Self-Created Model Arch with Augmented Data & Callback(s)**

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])

# %%
model.summary()

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=80,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(150, 150))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(150, 150))

# %%
# Defining Callbacks

# Save the best model
file_path = '/content/checkpoint/self_created'
checkpoint_callback = ModelCheckpoint(filepath=file_path, save_best_only=True, monitor='val_accuracy', verbose=2)

# Early stopping
early_stopping_callback = EarlyStopping(monitor='val_accuracy', patience=10, verbose=2, restore_best_weights=True)

# Reduce learning rate
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=2, min_lr=1e-6)

callbacks=[checkpoint_callback, early_stopping_callback, reduce_lr_callback]

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=callbacks
    )

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Self-Created Model Arch with Augmented Data & Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Self-Created Model Arch with Augmented Data & Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # **Transfer Learning (Xception) with Augmented Data & Callback(s)**

# %%
from tensorflow.keras.applications import Xception

# %%
model = tf.keras.models.Sequential([
    # Xception Layer
    Xception(include_top=False, weights='imagenet', input_shape=(224, 224, 3)),
    # Max Pooling Layer
    tf.keras.layers.GlobalMaxPooling2D(),
    # Drop Out Layer
    tf.keras.layers.Dropout(0.2),
    # 256 neuron hidden layer
    tf.keras.layers.Dense(256, activation='relu'),
    # Output
    tf.keras.layers.Dense(2, activation='softmax') 
])

model.layers[0].trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 5s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  global_max_pooling2d (Globa  (None, 2048)             0
#  lMaxPooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 21,386,538
# Trainable params: 525,058
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=80,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(224, 224))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(224, 224))
# Out:
# Found 1016 images belonging to 2 classes.
# Found 174 images belonging to 2 classes.

# %%
# Defining Callbacks

# Save the best model
file_path = '/content/checkpoint/xception'
checkpoint_callback = ModelCheckpoint(filepath=file_path, save_best_only=True, monitor='val_accuracy', verbose=2)

# Early stopping
early_stopping_callback = EarlyStopping(monitor='val_accuracy', patience=10, verbose=2, restore_best_weights=True)

# Reduce learning rate
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=2, min_lr=1e-6)

callbacks=[checkpoint_callback, early_stopping_callback, reduce_lr_callback]

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=callbacks
    )
# Out:
# Epoch 1/50
# 32/32 [==============================] - ETA: 0s - loss: 0.7325 - accuracy: 0.8317
# Epoch 1: val_accuracy improved from -inf to 0.89655, saving model to /content/checkpoint/xception
# 32/32 [==============================] - 153s 4s/step - loss: 0.7325 - accuracy: 0.8317 - val_loss: 0.2800 - val_accuracy: 0.8966 - lr: 0.0010
# Epoch 2/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.9528
# Epoch 2: val_accuracy improved from 0.89655 to 0.91954, saving model to /content/checkpoint/xception
# 32/32 [==============================] - 36s 1s/step - loss: 0.1192 - accuracy: 0.9528 - val_loss: 0.2366 - val_accuracy: 0.9195 - lr: 0.0010
# Epoch 3/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1128 - accuracy: 0.9596
# Epoch 3: val_accuracy improved from 0.91954 to 0.93103, saving model to /content/checkpoint/xception
# 32/32 [==============================] - 35s 1s/step - loss: 0.1128 - accuracy: 0.9596 - val_loss: 0.1204 - val_accuracy: 0.9310 - lr: 0.0010
# Epoch 4/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1066 - accuracy: 0.9557
# Epoch 4: val_accuracy improved from 0.93103 to 0.94253, saving model to /content/checkpoint/xception
# 32/32 [==============================] - 37s 1s/step - loss: 0.1066 - accuracy: 0.9557 - val_loss: 0.1042 - val_accuracy: 0.9425 - lr: 0.0010
# Epoch 5/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.9705
# Epoch 5: val_accuracy did not improve from 0.94253
# 32/32 [==============================] - 17s 517ms/step - loss: 0.0681 - accuracy: 0.9705 - val_loss: 0.1462 - val_accuracy: 0.9310 - lr: 0.0010
# Epoch 6/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9774
# Epoch 6: val_accuracy did not improve from 0.94253
# 32/32 [==============================] - 16s 507ms/step - loss: 0.0782 - accuracy: 0.9774 - val_loss: 0.2676 - val_accuracy: 0.9253 - lr: 0.0010
# Epoch 7/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0769 - accuracy: 0.9695
# Epoch 7: val_accuracy improved from 0.94253 to 0.94828, saving model to /content/checkpoint/xception
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 32/32 [==============================] - 36s 1s/step - loss: 0.0769 - accuracy: 0.9695 - val_loss: 0.1056 - val_accuracy: 0.9483 - lr: 0.0010
# Epoch 8/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9783
# Epoch 8: val_accuracy did not improve from 0.94828
# 32/32 [==============================] - 16s 508ms/step - loss: 0.0551 - accuracy: 0.9783 - val_loss: 0.0986 - val_accuracy: 0.9483 - lr: 1.0000e-04
# Epoch 9/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.9734
# Epoch 9: val_accuracy did not improve from 0.94828
# 32/32 [==============================] - 16s 507ms/step - loss: 0.0681 - accuracy: 0.9734 - val_loss: 0.1042 - val_accuracy: 0.9425 - lr: 1.0000e-04
# Epoch 10/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9813
# Epoch 10: val_accuracy did not improve from 0.94828
# 32/32 [==============================] - 16s 504ms/step - loss: 0.0456 - accuracy: 0.9813 - val_loss: 0.0997 - val_accuracy: 0.9483 - lr: 1.0000e-04
# Epoch 11/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 0.9764
# Epoch 11: val_accuracy did not improve from 0.94828
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 32/32 [==============================] - 17s 543ms/step - loss: 0.0593 - accuracy: 0.9764 - val_loss: 0.1051 - val_accuracy: 0.9483 - lr: 1.0000e-04
# Epoch 12/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0729 - accuracy: 0.9744
# Epoch 12: val_accuracy did not improve from 0.94828
# 32/32 [==============================] - 16s 504ms/step - loss: 0.0729 - accuracy: 0.9744 - val_loss: 0.1071 - val_accuracy: 0.9425 - lr: 1.0000e-05
# Epoch 13/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0547 - accuracy: 0.9793
# Epoch 13: val_accuracy did not improve from 0.94828
# 32/32 [==============================] - 17s 519ms/step - loss: 0.0547 - accuracy: 0.9793 - val_loss: 0.1099 - val_accuracy: 0.9425 - lr: 1.0000e-05
# Epoch 14/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0537 - accuracy: 0.9774
# Epoch 14: val_accuracy did not improve from 0.94828
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 32/32 [==============================] - 16s 502ms/step - loss: 0.0537 - accuracy: 0.9774 - val_loss: 0.1104 - val_accuracy: 0.9425 - lr: 1.0000e-05
# Epoch 15/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0538 - accuracy: 0.9783
# Epoch 15: val_accuracy did not improve from 0.94828
# 32/32 [==============================] - 16s 502ms/step - loss: 0.0538 - accuracy: 0.9783 - val_loss: 0.1102 - val_accuracy: 0.9425 - lr: 1.0000e-06
# Epoch 16/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9813
# Epoch 16: val_accuracy did not improve from 0.94828
# 32/32 [==============================] - 17s 514ms/step - loss: 0.0546 - accuracy: 0.9813 - val_loss: 0.1101 - val_accuracy: 0.9425 - lr: 1.0000e-06
# Epoch 17/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 0.9724
# Epoch 17: val_accuracy did not improve from 0.94828
# Restoring model weights from the end of the best epoch: 7.
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1e-06.
# 32/32 [==============================] - 17s 522ms/step - loss: 0.0618 - accuracy: 0.9724 - val_loss: 0.1098 - val_accuracy: 0.9425 - lr: 1.0000e-06
# Epoch 17: early stopping

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Transfer Learning (Xception) with Augmented Data & Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Transfer Learning (Xception) with Augmented Data & Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# !zip -r /content/lime_xception.zip /content/checkpoint/xception
# Out:
#   adding: content/checkpoint/xception/ (stored 0%)
#   adding: content/checkpoint/xception/variables/ (stored 0%)
#   adding: content/checkpoint/xception/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: content/checkpoint/xception/variables/variables.index (deflated 76%)
#   adding: content/checkpoint/xception/assets/ (stored 0%)
#   adding: content/checkpoint/xception/fingerprint.pb (stored 0%)
#   adding: content/checkpoint/xception/saved_model.pb (deflated 92%)
#   adding: content/checkpoint/xception/keras_metadata.pb (deflated 96%)

# %%
files.download("/content/lime_xception.zip")

# %% [markdown]
# # **Transfer Learning (MobileNetV2) with Augmented Data & Callback(s)**

# %%
from tensorflow.keras.applications import MobileNetV2

# %%
model = tf.keras.models.Sequential([
    # MobileNetV2 Layer
    MobileNetV2(include_top=False, weights='imagenet', input_shape=(224, 224, 3)),
    # Max Pooling Layer
    tf.keras.layers.GlobalMaxPooling2D(),
    # Drop Out Layer
    tf.keras.layers.Dropout(0.2),
    # 256 neuron hidden layer
    tf.keras.layers.Dense(256, activation='relu'),
    # Output
    tf.keras.layers.Dense(2, activation='softmax') 
])

model.layers[0].trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 1s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_max_pooling2d_1 (Glo  (None, 1280)             0
#  balMaxPooling2D)
#
#  dropout_1 (Dropout)         (None, 1280)              0
#
#  dense_2 (Dense)             (None, 256)               327936
#
#  dense_3 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 2,586,434
# Trainable params: 328,450
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=80,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(224, 224))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(224, 224))
# Out:
# Found 1016 images belonging to 2 classes.
# Found 174 images belonging to 2 classes.

# %%
# Defining Callbacks

# Save the best model
file_path = '/content/checkpoint/mobilenetv2'
checkpoint_callback = ModelCheckpoint(filepath=file_path, save_best_only=True, monitor='val_accuracy', verbose=2)

# Early stopping
early_stopping_callback = EarlyStopping(monitor='val_accuracy', patience=10, verbose=2, restore_best_weights=True)

# Reduce learning rate
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=2, min_lr=1e-6)

callbacks=[checkpoint_callback, early_stopping_callback, reduce_lr_callback]

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=callbacks
    )
# Out:
# Epoch 1/50
# 32/32 [==============================] - ETA: 0s - loss: 1.8533 - accuracy: 0.8228
# Epoch 1: val_accuracy improved from -inf to 0.91379, saving model to /content/checkpoint/mobilenetv2
# 32/32 [==============================] - 47s 1s/step - loss: 1.8533 - accuracy: 0.8228 - val_loss: 0.2520 - val_accuracy: 0.9138 - lr: 0.0010
# Epoch 2/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9715
# Epoch 2: val_accuracy improved from 0.91379 to 0.94828, saving model to /content/checkpoint/mobilenetv2
# 32/32 [==============================] - 39s 1s/step - loss: 0.0746 - accuracy: 0.9715 - val_loss: 0.1063 - val_accuracy: 0.9483 - lr: 0.0010
# Epoch 3/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0592 - accuracy: 0.9803
# Epoch 3: val_accuracy did not improve from 0.94828
# 32/32 [==============================] - 16s 498ms/step - loss: 0.0592 - accuracy: 0.9803 - val_loss: 0.1768 - val_accuracy: 0.9368 - lr: 0.0010
# Epoch 4/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0566 - accuracy: 0.9793
# Epoch 4: val_accuracy improved from 0.94828 to 0.95977, saving model to /content/checkpoint/mobilenetv2
# 32/32 [==============================] - 38s 1s/step - loss: 0.0566 - accuracy: 0.9793 - val_loss: 0.0799 - val_accuracy: 0.9598 - lr: 0.0010
# Epoch 5/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0322 - accuracy: 0.9862
# Epoch 5: val_accuracy did not improve from 0.95977
# 32/32 [==============================] - 15s 483ms/step - loss: 0.0322 - accuracy: 0.9862 - val_loss: 0.1523 - val_accuracy: 0.9483 - lr: 0.0010
# Epoch 6/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9872
# Epoch 6: val_accuracy improved from 0.95977 to 0.97126, saving model to /content/checkpoint/mobilenetv2
# 32/32 [==============================] - 37s 1s/step - loss: 0.0453 - accuracy: 0.9872 - val_loss: 0.0684 - val_accuracy: 0.9713 - lr: 0.0010
# Epoch 7/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9833
# Epoch 7: val_accuracy improved from 0.97126 to 0.98276, saving model to /content/checkpoint/mobilenetv2
# 32/32 [==============================] - 39s 1s/step - loss: 0.0406 - accuracy: 0.9833 - val_loss: 0.0484 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 8/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.9911
# Epoch 8: val_accuracy did not improve from 0.98276
# 32/32 [==============================] - 15s 483ms/step - loss: 0.0259 - accuracy: 0.9911 - val_loss: 0.0503 - val_accuracy: 0.9770 - lr: 0.0010
# Epoch 9/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9862
# Epoch 9: val_accuracy did not improve from 0.98276
# 32/32 [==============================] - 15s 477ms/step - loss: 0.0283 - accuracy: 0.9862 - val_loss: 0.0783 - val_accuracy: 0.9598 - lr: 0.0010
# Epoch 10/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0457 - accuracy: 0.9852
# Epoch 10: val_accuracy did not improve from 0.98276
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 32/32 [==============================] - 15s 483ms/step - loss: 0.0457 - accuracy: 0.9852 - val_loss: 0.0553 - val_accuracy: 0.9770 - lr: 0.0010
# Epoch 11/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9872
# Epoch 11: val_accuracy did not improve from 0.98276
# 32/32 [==============================] - 16s 487ms/step - loss: 0.0256 - accuracy: 0.9872 - val_loss: 0.0525 - val_accuracy: 0.9770 - lr: 1.0000e-04
# Epoch 12/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9941
# Epoch 12: val_accuracy did not improve from 0.98276
# 32/32 [==============================] - 16s 490ms/step - loss: 0.0157 - accuracy: 0.9941 - val_loss: 0.0526 - val_accuracy: 0.9713 - lr: 1.0000e-04
# Epoch 13/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 0.9970
# Epoch 13: val_accuracy did not improve from 0.98276
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 32/32 [==============================] - 16s 493ms/step - loss: 0.0144 - accuracy: 0.9970 - val_loss: 0.0500 - val_accuracy: 0.9770 - lr: 1.0000e-04
# Epoch 14/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9951
# Epoch 14: val_accuracy did not improve from 0.98276
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0182 - accuracy: 0.9951 - val_loss: 0.0497 - val_accuracy: 0.9770 - lr: 1.0000e-05
# Epoch 15/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9921
# Epoch 15: val_accuracy did not improve from 0.98276
# 32/32 [==============================] - 16s 503ms/step - loss: 0.0199 - accuracy: 0.9921 - val_loss: 0.0494 - val_accuracy: 0.9770 - lr: 1.0000e-05
# Epoch 16/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 0.9941
# Epoch 16: val_accuracy did not improve from 0.98276
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 32/32 [==============================] - 17s 540ms/step - loss: 0.0152 - accuracy: 0.9941 - val_loss: 0.0492 - val_accuracy: 0.9770 - lr: 1.0000e-05
# Epoch 17/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0219 - accuracy: 0.9921
# Epoch 17: val_accuracy did not improve from 0.98276
# Restoring model weights from the end of the best epoch: 7.
# 32/32 [==============================] - 16s 516ms/step - loss: 0.0219 - accuracy: 0.9921 - val_loss: 0.0492 - val_accuracy: 0.9770 - lr: 1.0000e-06
# Epoch 17: early stopping

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Transfer Learning (MobileNetV2) with Augmented Data & Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Transfer Learning (MobileNetV2) with Augmented Data & Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# !zip -r /content/lime_mobilenetv2.zip /content/checkpoint/mobilenetv2
# Out:
#   adding: content/checkpoint/mobilenetv2/ (stored 0%)
#   adding: content/checkpoint/mobilenetv2/variables/ (stored 0%)
#   adding: content/checkpoint/mobilenetv2/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: content/checkpoint/mobilenetv2/variables/variables.index (deflated 75%)
#   adding: content/checkpoint/mobilenetv2/assets/ (stored 0%)
#   adding: content/checkpoint/mobilenetv2/fingerprint.pb (stored 0%)
#   adding: content/checkpoint/mobilenetv2/saved_model.pb (deflated 91%)
#   adding: content/checkpoint/mobilenetv2/keras_metadata.pb (deflated 96%)

# %%
files.download("/content/lime_mobilenetv2.zip")

# %% [markdown]
# # **Transfer Learning (Densenet121) with Augmented Data & Callback(s)**

# %%
from tensorflow.keras.applications import DenseNet121

# %%
model = tf.keras.models.Sequential([
    # DenseNet121 Layer
    DenseNet121(include_top=False, weights='imagenet', input_shape=(224, 224, 3)),
    # Max Pooling Layer
    tf.keras.layers.GlobalMaxPooling2D(),
    # Drop Out Layer
    tf.keras.layers.Dropout(0.2),
    # 256 neuron hidden layer
    tf.keras.layers.Dense(256, activation='relu'),
    # Output
    tf.keras.layers.Dense(2, activation='softmax') 
])

model.layers[0].trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet121 (Functional)    (None, 7, 7, 1024)        7037504
#
#  global_max_pooling2d_2 (Glo  (None, 1024)             0
#  balMaxPooling2D)
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 256)               262400
#
#  dense_5 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 7,300,418
# Trainable params: 262,914
# Non-trainable params: 7,037,504
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=80,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(224, 224))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(224, 224))
# Out:
# Found 1016 images belonging to 2 classes.
# Found 174 images belonging to 2 classes.

# %%
# Defining Callbacks

# Save the best model
file_path = '/content/checkpoint/densenet121'
checkpoint_callback = ModelCheckpoint(filepath=file_path, save_best_only=True, monitor='val_accuracy', verbose=2)

# Early stopping
early_stopping_callback = EarlyStopping(monitor='val_accuracy', patience=10, verbose=2, restore_best_weights=True)

# Reduce learning rate
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=2, min_lr=1e-6)

callbacks=[checkpoint_callback, early_stopping_callback, reduce_lr_callback]

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=callbacks
    )
# Out:
# Epoch 1/50
# 32/32 [==============================] - ETA: 0s - loss: 0.8291 - accuracy: 0.8711
# Epoch 1: val_accuracy improved from -inf to 0.97701, saving model to /content/checkpoint/densenet121
# 32/32 [==============================] - 83s 2s/step - loss: 0.8291 - accuracy: 0.8711 - val_loss: 0.2050 - val_accuracy: 0.9770 - lr: 0.0010
# Epoch 2/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1565 - accuracy: 0.9734
# Epoch 2: val_accuracy improved from 0.97701 to 0.98276, saving model to /content/checkpoint/densenet121
# 32/32 [==============================] - 69s 2s/step - loss: 0.1565 - accuracy: 0.9734 - val_loss: 0.0805 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 3/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9872
# Epoch 3: val_accuracy improved from 0.98276 to 0.98851, saving model to /content/checkpoint/densenet121
# 32/32 [==============================] - 68s 2s/step - loss: 0.0295 - accuracy: 0.9872 - val_loss: 0.0549 - val_accuracy: 0.9885 - lr: 0.0010
# Epoch 4/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0322 - accuracy: 0.9892
# Epoch 4: val_accuracy did not improve from 0.98851
# 32/32 [==============================] - 16s 486ms/step - loss: 0.0322 - accuracy: 0.9892 - val_loss: 0.0775 - val_accuracy: 0.9770 - lr: 0.0010
# Epoch 5/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0837 - accuracy: 0.9823
# Epoch 5: val_accuracy did not improve from 0.98851
# 32/32 [==============================] - 16s 494ms/step - loss: 0.0837 - accuracy: 0.9823 - val_loss: 0.0436 - val_accuracy: 0.9885 - lr: 0.0010
# Epoch 6/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9882
# Epoch 6: val_accuracy improved from 0.98851 to 0.99425, saving model to /content/checkpoint/densenet121
# 32/32 [==============================] - 70s 2s/step - loss: 0.0436 - accuracy: 0.9882 - val_loss: 0.0399 - val_accuracy: 0.9943 - lr: 0.0010
# Epoch 7/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9911
# Epoch 7: val_accuracy did not improve from 0.99425
# 32/32 [==============================] - 17s 532ms/step - loss: 0.0332 - accuracy: 0.9911 - val_loss: 0.0385 - val_accuracy: 0.9885 - lr: 0.0010
# Epoch 8/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0935 - accuracy: 0.9833
# Epoch 8: val_accuracy did not improve from 0.99425
# 32/32 [==============================] - 16s 505ms/step - loss: 0.0935 - accuracy: 0.9833 - val_loss: 0.0602 - val_accuracy: 0.9885 - lr: 0.0010
# Epoch 9/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0524 - accuracy: 0.9872
# Epoch 9: val_accuracy did not improve from 0.99425
# 32/32 [==============================] - 16s 496ms/step - loss: 0.0524 - accuracy: 0.9872 - val_loss: 0.1717 - val_accuracy: 0.9713 - lr: 0.0010
# Epoch 10/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9961
# Epoch 10: val_accuracy did not improve from 0.99425
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 32/32 [==============================] - 16s 496ms/step - loss: 0.0100 - accuracy: 0.9961 - val_loss: 0.0604 - val_accuracy: 0.9885 - lr: 0.0010
# Epoch 11/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 0.9921
# Epoch 11: val_accuracy did not improve from 0.99425
# 32/32 [==============================] - 16s 495ms/step - loss: 0.0258 - accuracy: 0.9921 - val_loss: 0.0589 - val_accuracy: 0.9885 - lr: 1.0000e-04
# Epoch 12/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9951
# Epoch 12: val_accuracy did not improve from 0.99425
# 32/32 [==============================] - 17s 538ms/step - loss: 0.0167 - accuracy: 0.9951 - val_loss: 0.0565 - val_accuracy: 0.9885 - lr: 1.0000e-04
# Epoch 13/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9941
# Epoch 13: val_accuracy did not improve from 0.99425
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 32/32 [==============================] - 16s 493ms/step - loss: 0.0179 - accuracy: 0.9941 - val_loss: 0.0560 - val_accuracy: 0.9885 - lr: 1.0000e-04
# Epoch 14/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9951
# Epoch 14: val_accuracy did not improve from 0.99425
# 32/32 [==============================] - 16s 510ms/step - loss: 0.0097 - accuracy: 0.9951 - val_loss: 0.0559 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 15/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9951
# Epoch 15: val_accuracy did not improve from 0.99425
# 32/32 [==============================] - 16s 491ms/step - loss: 0.0186 - accuracy: 0.9951 - val_loss: 0.0554 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 16/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9941
# Epoch 16: val_accuracy did not improve from 0.99425
# Restoring model weights from the end of the best epoch: 6.
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 32/32 [==============================] - 17s 534ms/step - loss: 0.0138 - accuracy: 0.9941 - val_loss: 0.0549 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 16: early stopping

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Transfer Learning (DenseNet121) with Augmented Data & Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Transfer Learning (DenseNet121) with Augmented Data & Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# !zip -r /content/lime_densenet121.zip /content/checkpoint/densenet121
# Out:
#   adding: content/checkpoint/densenet121/ (stored 0%)
#   adding: content/checkpoint/densenet121/variables/ (stored 0%)
#   adding: content/checkpoint/densenet121/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: content/checkpoint/densenet121/variables/variables.index (deflated 78%)
#   adding: content/checkpoint/densenet121/assets/ (stored 0%)
#   adding: content/checkpoint/densenet121/fingerprint.pb (stored 0%)
#   adding: content/checkpoint/densenet121/saved_model.pb (deflated 92%)
#   adding: content/checkpoint/densenet121/keras_metadata.pb (deflated 96%)

# %%
files.download("/content/lime_densenet121.zip")
