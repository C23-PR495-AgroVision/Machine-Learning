# %% [markdown]
# # **Preparations**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

base_dir = '/content/drive/MyDrive/Pomegranate'

print("Contents of base directory:")
print(os.listdir(base_dir))

print("\nContents of train directory:")
print(os.listdir(f'{base_dir}/train'))

print("\nContents of validation directory:")
print(os.listdir(f'{base_dir}/valid'))
# Out:
# Contents of base directory:
# ['valid', 'train']
#
# Contents of train directory:
# ['bad', 'good']
#
# Contents of validation directory:
# ['good', 'bad']

# %%
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'valid')

# Directory with training pictures
train_bad_dir = os.path.join(train_dir, 'bad')
train_good_dir = os.path.join(train_dir, 'good')

# Directory with validation pictures
validation_bad_dir = os.path.join(validation_dir, 'bad')
validation_good_dir = os.path.join(validation_dir, 'good')

# %%
train_bad_fnames = os.listdir(train_bad_dir)
train_good_fnames = os.listdir(train_good_dir)

print(train_bad_fnames[:10])
print(train_good_fnames[:10])
# Out:
# ['IMG20200728182502.jpg', 'IMG20200728182506_12.jpg', 'IMG20200728182507.jpg', 'IMG20200728182504.jpg', 'IMG20200728182502_01.jpg', 'IMG20200728182503.jpg', 'IMG20200728182530.jpg', 'IMG20200728182527.jpg', 'IMG20200728182508.jpg', 'IMG20200728182514.jpg']
# ['IMG20200728125422_26973.jpg', 'IMG20200728125424_26976.jpg', 'IMG20200728125424_26978.jpg', 'IMG20200728125427_26981.jpg', 'IMG20200728125430_26986.jpg', 'IMG20200728125432_26988.jpg', 'IMG20200728125432_26990.jpg', 'IMG20200728125432_26989.jpg', 'IMG20200728125443_26992.jpg', 'IMG20200728125443_26993.jpg']

# %%
print('total training `bad` images:', len(os.listdir(train_bad_dir)))
print('total training `good` images:', len(os.listdir(train_good_dir)))

print('total validation `bad` images:', len(os.listdir(validation_bad_dir)))
print('total validation `good` images:', len(os.listdir(validation_good_dir)))
# Out:
# total training `bad` images: 688
# total training `good` images: 176
# total validation `bad` images: 110
# total validation `good` images: 49

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

nrows = 4
ncols = 4

pic_index = 0

# %%
fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

pic_index += 8

next_bad_pix = [os.path.join(train_bad_dir, fname) 
                for fname in train_bad_fnames[pic_index-8 : pic_index] 
               ]

next_good_pix = [os.path.join(train_good_dir, fname) 
                for fname in train_good_fnames[ pic_index-8 : pic_index]
               ]

for i, img_path in enumerate(next_bad_pix + next_good_pix):
  sp = plt.subplot(nrows, ncols, i+1)
  sp.axis('Off')
  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
from google.colab import files

# %% [markdown]
# # **Self-Created Model Arch with Non-Augmented Data & No Callback(s)**

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])

# %%
model.summary()

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255.)
test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(150, 150))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(150, 150))

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator
    )

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Self-Created Model Arch with Non-Augmented Data & No Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Self-Created Model Arch with Non-Augmented Data & No Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # **Self-Created Model Arch with Augmented Data & Callback(s)**

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])

# %%
model.summary()

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=80,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(150, 150))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(150, 150))

# %%
# Defining Callbacks

# Save the best model
file_path = '/content/checkpoint/self_created'
checkpoint_callback = ModelCheckpoint(filepath=file_path, save_best_only=True, monitor='val_accuracy', verbose=2)

# Early stopping
early_stopping_callback = EarlyStopping(monitor='val_accuracy', patience=10, verbose=2, restore_best_weights=True)

# Reduce learning rate
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=2, min_lr=1e-6)

callbacks=[checkpoint_callback, early_stopping_callback, reduce_lr_callback]

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=callbacks
    )

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Self-Created Model Arch with Augmented Data & Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Self-Created Model Arch with Augmented Data & Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # **Transfer Learning (Xception) with Augmented Data & Callback(s)**

# %%
from tensorflow.keras.applications import Xception

# %%
model = tf.keras.models.Sequential([
    # Xception Layer
    Xception(include_top=False, weights='imagenet', input_shape=(224, 224, 3)),
    # Max Pooling Layer
    tf.keras.layers.GlobalMaxPooling2D(),
    # Drop Out Layer
    tf.keras.layers.Dropout(0.2),
    # 256 neuron hidden layer
    tf.keras.layers.Dense(256, activation='relu'),
    # Output
    tf.keras.layers.Dense(2, activation='softmax') 
])

model.layers[0].trainable = False

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  global_max_pooling2d_1 (Glo  (None, 2048)             0
#  balMaxPooling2D)
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 256)               524544
#
#  dense_3 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 21,386,538
# Trainable params: 525,058
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=80,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(224, 224))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(224, 224))
# Out:
# Found 864 images belonging to 2 classes.
# Found 159 images belonging to 2 classes.

# %%
# Defining Callbacks

# Save the best model
file_path = '/content/checkpoint/xception'
checkpoint_callback = ModelCheckpoint(filepath=file_path, save_best_only=True, monitor='val_accuracy', verbose=2)

# Early stopping
early_stopping_callback = EarlyStopping(monitor='val_accuracy', patience=10, verbose=2, restore_best_weights=True)

# Reduce learning rate
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=2, min_lr=1e-6)

callbacks=[checkpoint_callback, early_stopping_callback, reduce_lr_callback]

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=callbacks
    )
# Out:
# Epoch 1/50
# 27/27 [==============================] - ETA: 0s - loss: 1.1359 - accuracy: 0.7951
# Epoch 1: val_accuracy improved from -inf to 0.96226, saving model to /content/checkpoint/xception
# 27/27 [==============================] - 83s 3s/step - loss: 1.1359 - accuracy: 0.7951 - val_loss: 0.1048 - val_accuracy: 0.9623 - lr: 0.0010
# Epoch 2/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0955 - accuracy: 0.9688
# Epoch 2: val_accuracy improved from 0.96226 to 0.98113, saving model to /content/checkpoint/xception
# 27/27 [==============================] - 76s 3s/step - loss: 0.0955 - accuracy: 0.9688 - val_loss: 0.0382 - val_accuracy: 0.9811 - lr: 0.0010
# Epoch 3/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0725 - accuracy: 0.9711
# Epoch 3: val_accuracy did not improve from 0.98113
# 27/27 [==============================] - 57s 2s/step - loss: 0.0725 - accuracy: 0.9711 - val_loss: 0.0594 - val_accuracy: 0.9811 - lr: 0.0010
# Epoch 4/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9896
# Epoch 4: val_accuracy improved from 0.98113 to 0.98742, saving model to /content/checkpoint/xception
# 27/27 [==============================] - 75s 3s/step - loss: 0.0428 - accuracy: 0.9896 - val_loss: 0.0283 - val_accuracy: 0.9874 - lr: 0.0010
# Epoch 5/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9792
# Epoch 5: val_accuracy improved from 0.98742 to 0.99371, saving model to /content/checkpoint/xception
# 27/27 [==============================] - 87s 3s/step - loss: 0.0617 - accuracy: 0.9792 - val_loss: 0.0222 - val_accuracy: 0.9937 - lr: 0.0010
# Epoch 6/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9711
# Epoch 6: val_accuracy did not improve from 0.99371
# 27/27 [==============================] - 57s 2s/step - loss: 0.0677 - accuracy: 0.9711 - val_loss: 0.0172 - val_accuracy: 0.9937 - lr: 0.0010
# Epoch 7/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0443 - accuracy: 0.9838
# Epoch 7: val_accuracy did not improve from 0.99371
# 27/27 [==============================] - 55s 2s/step - loss: 0.0443 - accuracy: 0.9838 - val_loss: 0.0165 - val_accuracy: 0.9937 - lr: 0.0010
# Epoch 8/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9826
# Epoch 8: val_accuracy did not improve from 0.99371
# 27/27 [==============================] - 57s 2s/step - loss: 0.0479 - accuracy: 0.9826 - val_loss: 0.0165 - val_accuracy: 0.9937 - lr: 0.0010
# Epoch 9/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0382 - accuracy: 0.9896
# Epoch 9: val_accuracy did not improve from 0.99371
# 27/27 [==============================] - 55s 2s/step - loss: 0.0382 - accuracy: 0.9896 - val_loss: 0.0129 - val_accuracy: 0.9937 - lr: 0.0010
# Epoch 10/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0221 - accuracy: 0.9942
# Epoch 10: val_accuracy did not improve from 0.99371
# 27/27 [==============================] - 54s 2s/step - loss: 0.0221 - accuracy: 0.9942 - val_loss: 0.0176 - val_accuracy: 0.9874 - lr: 0.0010
# Epoch 11/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9884
# Epoch 11: val_accuracy did not improve from 0.99371
# 27/27 [==============================] - 57s 2s/step - loss: 0.0404 - accuracy: 0.9884 - val_loss: 0.0368 - val_accuracy: 0.9874 - lr: 0.0010
# Epoch 12/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0471 - accuracy: 0.9815
# Epoch 12: val_accuracy did not improve from 0.99371
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 27/27 [==============================] - 55s 2s/step - loss: 0.0471 - accuracy: 0.9815 - val_loss: 0.0142 - val_accuracy: 0.9937 - lr: 0.0010
# Epoch 13/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9931
# Epoch 13: val_accuracy did not improve from 0.99371
# 27/27 [==============================] - 56s 2s/step - loss: 0.0197 - accuracy: 0.9931 - val_loss: 0.0149 - val_accuracy: 0.9937 - lr: 1.0000e-04
# Epoch 14/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9896
# Epoch 14: val_accuracy did not improve from 0.99371
# 27/27 [==============================] - 57s 2s/step - loss: 0.0265 - accuracy: 0.9896 - val_loss: 0.0128 - val_accuracy: 0.9937 - lr: 1.0000e-04
# Epoch 15/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0221 - accuracy: 0.9942
# Epoch 15: val_accuracy did not improve from 0.99371
# Restoring model weights from the end of the best epoch: 5.
# 27/27 [==============================] - 65s 2s/step - loss: 0.0221 - accuracy: 0.9942 - val_loss: 0.0173 - val_accuracy: 0.9937 - lr: 1.0000e-04
# Epoch 15: early stopping

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Transfer Learning (Xception) with Augmented Data & Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Transfer Learning (Xception) with Augmented Data & Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# !zip -r /content/pomegranate_xception.zip /content/checkpoint/xception
# Out:
#   adding: content/checkpoint/xception/ (stored 0%)
#   adding: content/checkpoint/xception/variables/ (stored 0%)
#   adding: content/checkpoint/xception/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: content/checkpoint/xception/variables/variables.index (deflated 76%)
#   adding: content/checkpoint/xception/assets/ (stored 0%)
#   adding: content/checkpoint/xception/fingerprint.pb (stored 0%)
#   adding: content/checkpoint/xception/saved_model.pb (deflated 92%)
#   adding: content/checkpoint/xception/keras_metadata.pb (deflated 96%)

# %%
files.download("/content/pomegranate_xception.zip")

# %% [markdown]
# # **Transfer Learning (MobileNetV2) with Augmented Data & Callback(s)**

# %%
from tensorflow.keras.applications import MobileNetV2

# %%
model = tf.keras.models.Sequential([
    # MobileNetV2 Layer
    MobileNetV2(include_top=False, weights='imagenet', input_shape=(224, 224, 3)),
    # Max Pooling Layer
    tf.keras.layers.GlobalMaxPooling2D(),
    # Drop Out Layer
    tf.keras.layers.Dropout(0.2),
    # 256 neuron hidden layer
    tf.keras.layers.Dense(256, activation='relu'),
    # Output
    tf.keras.layers.Dense(2, activation='softmax') 
])

model.layers[0].trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 1s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_max_pooling2d_2 (Glo  (None, 1280)             0
#  balMaxPooling2D)
#
#  dropout_2 (Dropout)         (None, 1280)              0
#
#  dense_4 (Dense)             (None, 256)               327936
#
#  dense_5 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 2,586,434
# Trainable params: 328,450
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=80,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(224, 224))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(224, 224))
# Out:
# Found 864 images belonging to 2 classes.
# Found 159 images belonging to 2 classes.

# %%
# Defining Callbacks

# Save the best model
file_path = '/content/checkpoint/mobilenetv2'
checkpoint_callback = ModelCheckpoint(filepath=file_path, save_best_only=True, monitor='val_accuracy', verbose=2)

# Early stopping
early_stopping_callback = EarlyStopping(monitor='val_accuracy', patience=10, verbose=2, restore_best_weights=True)

# Reduce learning rate
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=2, min_lr=1e-6)

callbacks=[checkpoint_callback, early_stopping_callback, reduce_lr_callback]

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=callbacks
    )
# Out:
# Epoch 1/50
# 27/27 [==============================] - ETA: 0s - loss: 1.4079 - accuracy: 0.8484
# Epoch 1: val_accuracy improved from -inf to 0.90566, saving model to /content/checkpoint/mobilenetv2
# 27/27 [==============================] - 85s 3s/step - loss: 1.4079 - accuracy: 0.8484 - val_loss: 0.5573 - val_accuracy: 0.9057 - lr: 0.0010
# Epoch 2/50
# 27/27 [==============================] - ETA: 0s - loss: 0.2075 - accuracy: 0.9491
# Epoch 2: val_accuracy improved from 0.90566 to 0.96855, saving model to /content/checkpoint/mobilenetv2
# 27/27 [==============================] - 76s 3s/step - loss: 0.2075 - accuracy: 0.9491 - val_loss: 0.0928 - val_accuracy: 0.9686 - lr: 0.0010
# Epoch 3/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1243 - accuracy: 0.9653
# Epoch 3: val_accuracy improved from 0.96855 to 0.99371, saving model to /content/checkpoint/mobilenetv2
# 27/27 [==============================] - 79s 3s/step - loss: 0.1243 - accuracy: 0.9653 - val_loss: 0.0243 - val_accuracy: 0.9937 - lr: 0.0010
# Epoch 4/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9850
# Epoch 4: val_accuracy did not improve from 0.99371
# 27/27 [==============================] - 56s 2s/step - loss: 0.0404 - accuracy: 0.9850 - val_loss: 0.0656 - val_accuracy: 0.9686 - lr: 0.0010
# Epoch 5/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9838
# Epoch 5: val_accuracy did not improve from 0.99371
# 27/27 [==============================] - 66s 2s/step - loss: 0.0617 - accuracy: 0.9838 - val_loss: 0.0756 - val_accuracy: 0.9623 - lr: 0.0010
# Epoch 6/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.9873
# Epoch 6: val_accuracy improved from 0.99371 to 1.00000, saving model to /content/checkpoint/mobilenetv2
# 27/27 [==============================] - 75s 3s/step - loss: 0.0317 - accuracy: 0.9873 - val_loss: 0.0146 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 7/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0330 - accuracy: 0.9896
# Epoch 7: val_accuracy did not improve from 1.00000
# 27/27 [==============================] - 55s 2s/step - loss: 0.0330 - accuracy: 0.9896 - val_loss: 0.0357 - val_accuracy: 0.9937 - lr: 0.0010
# Epoch 8/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0452 - accuracy: 0.9850
# Epoch 8: val_accuracy did not improve from 1.00000
# 27/27 [==============================] - 56s 2s/step - loss: 0.0452 - accuracy: 0.9850 - val_loss: 0.0158 - val_accuracy: 0.9937 - lr: 0.0010
# Epoch 9/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.9838
# Epoch 9: val_accuracy did not improve from 1.00000
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 27/27 [==============================] - 53s 2s/step - loss: 0.0464 - accuracy: 0.9838 - val_loss: 0.0627 - val_accuracy: 0.9748 - lr: 0.0010
# Epoch 10/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0357 - accuracy: 0.9931
# Epoch 10: val_accuracy did not improve from 1.00000
# 27/27 [==============================] - 54s 2s/step - loss: 0.0357 - accuracy: 0.9931 - val_loss: 0.0156 - val_accuracy: 0.9937 - lr: 1.0000e-04
# Epoch 11/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9884
# Epoch 11: val_accuracy did not improve from 1.00000
# 27/27 [==============================] - 56s 2s/step - loss: 0.0341 - accuracy: 0.9884 - val_loss: 0.0206 - val_accuracy: 0.9937 - lr: 1.0000e-04
# Epoch 12/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0292 - accuracy: 0.9931
# Epoch 12: val_accuracy did not improve from 1.00000
# 27/27 [==============================] - 54s 2s/step - loss: 0.0292 - accuracy: 0.9931 - val_loss: 0.0112 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 13/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9896
# Epoch 13: val_accuracy did not improve from 1.00000
# 27/27 [==============================] - 54s 2s/step - loss: 0.0229 - accuracy: 0.9896 - val_loss: 0.0310 - val_accuracy: 0.9811 - lr: 1.0000e-04
# Epoch 14/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9896
# Epoch 14: val_accuracy did not improve from 1.00000
# 27/27 [==============================] - 55s 2s/step - loss: 0.0301 - accuracy: 0.9896 - val_loss: 0.0200 - val_accuracy: 0.9937 - lr: 1.0000e-04
# Epoch 15/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9919
# Epoch 15: val_accuracy did not improve from 1.00000
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 27/27 [==============================] - 55s 2s/step - loss: 0.0165 - accuracy: 0.9919 - val_loss: 0.0112 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 16/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0173 - accuracy: 0.9965
# Epoch 16: val_accuracy did not improve from 1.00000
# Restoring model weights from the end of the best epoch: 6.
# 27/27 [==============================] - 54s 2s/step - loss: 0.0173 - accuracy: 0.9965 - val_loss: 0.0116 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 16: early stopping

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Transfer Learning (MobileNetV2) with Augmented Data & Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Transfer Learning (MobileNetV2) with Augmented Data & Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# !zip -r /content/pomegranate_mobilenetv2.zip /content/checkpoint/mobilenetv2
# Out:
#   adding: content/checkpoint/mobilenetv2/ (stored 0%)
#   adding: content/checkpoint/mobilenetv2/variables/ (stored 0%)
#   adding: content/checkpoint/mobilenetv2/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: content/checkpoint/mobilenetv2/variables/variables.index (deflated 76%)
#   adding: content/checkpoint/mobilenetv2/assets/ (stored 0%)
#   adding: content/checkpoint/mobilenetv2/fingerprint.pb (stored 0%)
#   adding: content/checkpoint/mobilenetv2/saved_model.pb (deflated 91%)
#   adding: content/checkpoint/mobilenetv2/keras_metadata.pb (deflated 96%)

# %%
files.download("/content/pomegranate_mobilenetv2.zip")

# %% [markdown]
# # **Transfer Learning (Densenet121) with Augmented Data & Callback(s)**

# %%
from tensorflow.keras.applications import DenseNet121

# %%
model = tf.keras.models.Sequential([
    # DenseNet121 Layer
    DenseNet121(include_top=False, weights='imagenet', input_shape=(224, 224, 3)),
    # Max Pooling Layer
    tf.keras.layers.GlobalMaxPooling2D(),
    # Drop Out Layer
    tf.keras.layers.Dropout(0.2),
    # 256 neuron hidden layer
    tf.keras.layers.Dense(256, activation='relu'),
    # Output
    tf.keras.layers.Dense(2, activation='softmax') 
])

model.layers[0].trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 3s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet121 (Functional)    (None, 7, 7, 1024)        7037504
#
#  global_max_pooling2d_3 (Glo  (None, 1024)             0
#  balMaxPooling2D)
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_6 (Dense)             (None, 256)               262400
#
#  dense_7 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 7,300,418
# Trainable params: 262,914
# Non-trainable params: 7,037,504
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=80,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(224, 224))     

validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        target_size=(224, 224))
# Out:
# Found 864 images belonging to 2 classes.
# Found 159 images belonging to 2 classes.

# %%
# Defining Callbacks

# Save the best model
file_path = '/content/checkpoint/densenet121'
checkpoint_callback = ModelCheckpoint(filepath=file_path, save_best_only=True, monitor='val_accuracy', verbose=2)

# Early stopping
early_stopping_callback = EarlyStopping(monitor='val_accuracy', patience=10, verbose=2, restore_best_weights=True)

# Reduce learning rate
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=2, min_lr=1e-6)

callbacks=[checkpoint_callback, early_stopping_callback, reduce_lr_callback]

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=callbacks
    )
# Out:
# Epoch 1/50
# 27/27 [==============================] - ETA: 0s - loss: 0.4924 - accuracy: 0.9120
# Epoch 1: val_accuracy improved from -inf to 0.98742, saving model to /content/checkpoint/densenet121
# 27/27 [==============================] - 121s 4s/step - loss: 0.4924 - accuracy: 0.9120 - val_loss: 0.0519 - val_accuracy: 0.9874 - lr: 0.0010
# Epoch 2/50
# 27/27 [==============================] - ETA: 0s - loss: 0.2390 - accuracy: 0.9479
# Epoch 2: val_accuracy did not improve from 0.98742
# 27/27 [==============================] - 55s 2s/step - loss: 0.2390 - accuracy: 0.9479 - val_loss: 0.4383 - val_accuracy: 0.9057 - lr: 0.0010
# Epoch 3/50
# 27/27 [==============================] - ETA: 0s - loss: 0.2386 - accuracy: 0.9491
# Epoch 3: val_accuracy did not improve from 0.98742
# 27/27 [==============================] - 54s 2s/step - loss: 0.2386 - accuracy: 0.9491 - val_loss: 0.1362 - val_accuracy: 0.9560 - lr: 0.0010
# Epoch 4/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1317 - accuracy: 0.9745
# Epoch 4: val_accuracy did not improve from 0.98742
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 27/27 [==============================] - 54s 2s/step - loss: 0.1317 - accuracy: 0.9745 - val_loss: 0.0894 - val_accuracy: 0.9686 - lr: 0.0010
# Epoch 5/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.9896
# Epoch 5: val_accuracy improved from 0.98742 to 0.99371, saving model to /content/checkpoint/densenet121
# 27/27 [==============================] - 105s 4s/step - loss: 0.0306 - accuracy: 0.9896 - val_loss: 0.0291 - val_accuracy: 0.9937 - lr: 1.0000e-04
# Epoch 6/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 0.9907
# Epoch 6: val_accuracy did not improve from 0.99371
# 27/27 [==============================] - 54s 2s/step - loss: 0.0432 - accuracy: 0.9907 - val_loss: 0.0507 - val_accuracy: 0.9811 - lr: 1.0000e-04
# Epoch 7/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9850
# Epoch 7: val_accuracy did not improve from 0.99371
# 27/27 [==============================] - 56s 2s/step - loss: 0.0371 - accuracy: 0.9850 - val_loss: 0.0320 - val_accuracy: 0.9937 - lr: 1.0000e-04
# Epoch 8/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0566 - accuracy: 0.9838
# Epoch 8: val_accuracy did not improve from 0.99371
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 27/27 [==============================] - 54s 2s/step - loss: 0.0566 - accuracy: 0.9838 - val_loss: 0.0705 - val_accuracy: 0.9811 - lr: 1.0000e-04
# Epoch 9/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9861
# Epoch 9: val_accuracy did not improve from 0.99371
# 27/27 [==============================] - 67s 3s/step - loss: 0.0403 - accuracy: 0.9861 - val_loss: 0.0611 - val_accuracy: 0.9811 - lr: 1.0000e-05
# Epoch 10/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0605 - accuracy: 0.9861
# Epoch 10: val_accuracy did not improve from 0.99371
# 27/27 [==============================] - 55s 2s/step - loss: 0.0605 - accuracy: 0.9861 - val_loss: 0.0535 - val_accuracy: 0.9811 - lr: 1.0000e-05
# Epoch 11/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9907
# Epoch 11: val_accuracy did not improve from 0.99371
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 27/27 [==============================] - 55s 2s/step - loss: 0.0281 - accuracy: 0.9907 - val_loss: 0.0496 - val_accuracy: 0.9811 - lr: 1.0000e-05
# Epoch 12/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9884
# Epoch 12: val_accuracy did not improve from 0.99371
# 27/27 [==============================] - 55s 2s/step - loss: 0.0281 - accuracy: 0.9884 - val_loss: 0.0499 - val_accuracy: 0.9811 - lr: 1.0000e-06
# Epoch 13/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9931
# Epoch 13: val_accuracy did not improve from 0.99371
# 27/27 [==============================] - 64s 2s/step - loss: 0.0266 - accuracy: 0.9931 - val_loss: 0.0502 - val_accuracy: 0.9811 - lr: 1.0000e-06
# Epoch 14/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9850
# Epoch 14: val_accuracy did not improve from 0.99371
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1e-06.
# 27/27 [==============================] - 55s 2s/step - loss: 0.0453 - accuracy: 0.9850 - val_loss: 0.0499 - val_accuracy: 0.9811 - lr: 1.0000e-06
# Epoch 15/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0365 - accuracy: 0.9873
# Epoch 15: val_accuracy did not improve from 0.99371
# Restoring model weights from the end of the best epoch: 5.
# 27/27 [==============================] - 65s 2s/step - loss: 0.0365 - accuracy: 0.9873 - val_loss: 0.0499 - val_accuracy: 0.9811 - lr: 1.0000e-06
# Epoch 15: early stopping

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy (Transfer Learning (DenseNet121) with Augmented Data & Callback(s))')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model (Transfer Learning (DenseNet121) with Augmented Data & Callback(s))')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# !zip -r /content/pomegranate_densenet121.zip /content/checkpoint/densenet121
# Out:
#   adding: content/checkpoint/densenet121/ (stored 0%)
#   adding: content/checkpoint/densenet121/variables/ (stored 0%)
#   adding: content/checkpoint/densenet121/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: content/checkpoint/densenet121/variables/variables.index (deflated 78%)
#   adding: content/checkpoint/densenet121/assets/ (stored 0%)
#   adding: content/checkpoint/densenet121/fingerprint.pb (stored 0%)
#   adding: content/checkpoint/densenet121/saved_model.pb (deflated 92%)
#   adding: content/checkpoint/densenet121/keras_metadata.pb (deflated 96%)

# %%
files.download("/content/pomegranate_densenet121.zip")
