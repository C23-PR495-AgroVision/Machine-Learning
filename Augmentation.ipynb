# %%
import imgaug.augmenters as iaa
import cv2
import os
import glob

# %%
# Define the augmentation transformations
seq = iaa.Sequential([
    iaa.Fliplr(0.5),  # horizontal flips
    iaa.Crop(percent=(0, 0.1)),  # random crops
    iaa.GaussianBlur(sigma=(0, 3.0)),  # gaussian blur
    iaa.AdditiveGaussianNoise(scale=(0, 0.05 * 255)),  # gaussian noise
    iaa.Multiply((0.8, 1.2)),  # brightness multiplier
    iaa.Affine(rotate=(-45, 45)),  # rotation
    iaa.ContrastNormalization((0.5, 2.0))  # contrast normalization
])

# Define the input directory and output directory
input_directory = 'Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe'
output_directory = 'Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe'

# Create the output directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)

# Get the list of image file paths in the input directory
image_paths = glob.glob(os.path.join(input_directory, '*.jpg'))

# Iterate through each image
for image_path in image_paths:
    # Load the input image
    input_image = cv2.imread(image_path)

    # Generate augmented images
    num_augmented_images = 30 # Number of augmented images to generate

    for i in range(num_augmented_images):
        # Perform augmentation on the input image
        augmented_image = seq.augment_image(input_image)

        # Get the filename from the image path
        filename = os.path.basename(image_path)

        # Construct the output path for the augmented image
        output_path = os.path.join(output_directory, f"augmented_{i}_{filename}")

        # Save the augmented image
        cv2.imwrite(output_path, augmented_image)

        print(f"Augmented image saved: {output_path}")
# Out:
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_0_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_1_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_2_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_3_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_4_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_5_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_6_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_7_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_8_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_9_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_10_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_11_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_12_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_13_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_14_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_15_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_16_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_17_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_18_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_19_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_20_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_21_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_22_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_23_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_24_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_25_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_26_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_27_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_28_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_29_IMG_20220530_085309.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_0_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_1_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_2_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_3_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_4_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_5_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_6_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_7_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_8_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_9_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_10_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_11_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_12_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_13_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_14_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_15_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_16_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_17_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_18_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_19_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_20_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_21_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_22_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_23_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_24_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_25_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_26_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_27_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_28_IMG_20220530_085311.jpg
# Augmented image saved: Vegetable Ripeness/Dataset/Bell Pepper/valid/unripe\augmented_29_IMG_20220530_085311.jpg
